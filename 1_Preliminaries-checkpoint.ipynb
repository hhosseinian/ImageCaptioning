# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will learn how to load and pre-process data from the [COCO dataset](http://cocodataset.org/#home). You will also design a CNN-RNN model for automatically generating image captions.
#
# You will use the instructions provided in **Step 3** and **Step 4** to implement your own CNN encoder and RNN decoder by making amendments to the **models.py** file provided as part of this project.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Explore the Data Loader
# - [Step 2](#step2): Use the Data Loader to Obtain Batches
# - [Step 3](#step3): Experiment with the CNN Encoder
# - [Step 4](#step4): Implement the RNN Decoder

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Explore the Data Loader
#
# You can use [data loader](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader) to load the COCO dataset in batches.
#
# In the code cell below, you will initialize the data loader by using the `get_loader` function in **data_loader.py**.
#
# > For this project, you are not permitted to change the **data_loader.py** file, which must be used as-is.
#
# The `get_loader` function takes as input a number of arguments that can be explored in **data_loader.py**.  Take the time to explore these arguments now by opening **data_loader.py** in a new window.  Most of the arguments must be left at their default values, and you are only allowed to amend the values of the arguments below:
# 1. **`transform`** - an [image transform](http://pytorch.org/docs/master/torchvision/transforms.html) specifying how to pre-process the images and convert them to PyTorch tensors before using them as input to the CNN encoder.  For now, you are encouraged to keep the transform as provided in `transform_train`.  You will have the opportunity later to choose your own image transform to pre-process the COCO images.
# 2. **`mode`** - one of `'train'` (loads the training data in batches) or `'test'` (for the test data). We will say that the data loader is in training or test mode, respectively.  While following the instructions in this notebook, please keep the data loader in training mode by setting `mode='train'`.
# 3. **`batch_size`** - determines the batch size.  When training the model, this is number of image-caption pairs used to amend the model weights in each training step.
# 4. **`vocab_threshold`** - the total number of times that a word must appear in the in the training captions before it is used as part of the vocabulary.  Words that have fewer than `vocab_threshold` occurrences in the training captions are considered unknown words.
# 5. **`vocab_from_file`** - a Boolean that decides whether to load the vocabulary from file.
#
# We will describe the `vocab_threshold` and `vocab_from_file` arguments in more detail soon.  For now, run the code cell below.  Be patient - it may take a couple of minutes to run!

# %%
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
import nltk
nltk.download('punkt')

########## Uncomment the block below for the first time you run this code on your system. Later you can comment them.############################################
# Download the COCO annotations
#!wget http://images.cocodataset.org/annotations/annotations_trainval2014.zip -P /coco
#Extract the downloaded file
#!unzip /coco/annotations_trainval2014.zip -d coco/
# Download the COCO images
#!wget http://images.cocodataset.org/zips/train2014.zip -P /coco
# Extract the downloaded file
#!unzip /coco/train2014.zip -d /coco

# Remove the zip file to save space
#!rm /coco/annotations_trainval2014.zip
#!rm /coco/train2014.zip
# !ls -l coco/annotations

#####################################################                       ##################################
# !wget https://raw.githubusercontent.com/hhosseinian/ImageCaptioning/main/data_loader_GGL_Colab.py #Uncomment if you run on google colab
#!wget https://raw.githubusercontent.com/hhosseinian/ImageCaptioning/main/vocabulary.py #Uncomment if you run on google colab
from data_loader_GGL_Colab import get_loader #Change it to "from data_loader import get_loader" if you run on local machine
from torchvision import transforms

# Define a transform to pre-process the training images.
transform_train = transforms.Compose([
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Set the minimum word count threshold.
vocab_threshold = 5

# Specify the batch size.
batch_size = 10

# Obtain the data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=False)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# total 825032
# -rw-rw-r-- 1 root root  66782097 Sep  1  2017 captions_train2014.json
# -rw-rw-r-- 1 root root  32421077 Sep  1  2017 captions_val2014.json
# -rw-rw-r-- 1 root root 332556225 Sep  1  2017 instances_train2014.json
# -rw-rw-r-- 1 root root 160682675 Sep  1  2017 instances_val2014.json
# -rw-r--r-- 1 root root 170733465 Sep  1  2017 person_keypoints_train2014.json
# -rw-r--r-- 1 root root  81637509 Sep  1  2017 person_keypoints_val2014.json
# --2024-07-28 08:07:02--  https://raw.githubusercontent.com/hhosseinian/ImageCaptioning/main/data_loader_GGL_Colab.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7151 (7.0K) [text/plain]
# Saving to: ‘data_loader_GGL_Colab.py’
#
# data_loader_GGL_Col 100%[===================>]   6.98K  --.-KB/s    in 0s
#
# 2024-07-28 08:07:02 (77.0 MB/s) - ‘data_loader_GGL_Colab.py’ saved [7151/7151]
#
# loading annotations into memory...
# Done (t=0.82s)
# creating index...
# index created!
# [0/414113] Tokenizing captions...
# [100000/414113] Tokenizing captions...
# [200000/414113] Tokenizing captions...
# [300000/414113] Tokenizing captions...
# [400000/414113] Tokenizing captions...
# loading annotations into memory...
# Done (t=0.74s)
# creating index...
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [00:56<00:00, 7389.07it/s]

# %% [markdown]
# When you ran the code cell above, the data loader was stored in the variable `data_loader`.
#
# You can access the corresponding dataset as `data_loader.dataset`.  This dataset is an instance of the `CoCoDataset` class in **data_loader.py**.  If you are unfamiliar with data loaders and datasets, you are encouraged to review [this PyTorch tutorial](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html).
#
# ### Exploring the `__getitem__` Method
#
# The `__getitem__` method in the `CoCoDataset` class determines how an image-caption pair is pre-processed before being incorporated into a batch.  This is true for all `Dataset` classes in PyTorch; if this is unfamiliar to you, please review [the tutorial linked above](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html).
#
# When the data loader is in training mode, this method begins by first obtaining the filename (`path`) of a training image and its corresponding caption (`caption`).
#
# #### Image Pre-Processing
#
# Image pre-processing is relatively straightforward (from the `__getitem__` method in the `CoCoDataset` class):
# ```python
# # Convert image to tensor and pre-process using transform
# image = Image.open(os.path.join(self.img_folder, path)).convert('RGB')
# image = self.transform(image)
# ```
# After loading the image in the training folder with name `path`, the image is pre-processed using the same transform (`transform_train`) that was supplied when instantiating the data loader.
#
# #### Caption Pre-Processing
#
# The captions also need to be pre-processed and prepped for training. In this example, for generating captions, we are aiming to create a model that predicts the next token of a sentence from previous tokens, so we turn the caption associated with any image into a list of tokenized words, before casting it to a PyTorch tensor that we can use to train the network.
#
# To understand in more detail how COCO captions are pre-processed, we'll first need to take a look at the `vocab` instance variable of the `CoCoDataset` class.  The code snippet below is pulled from the `__init__` method of the `CoCoDataset` class:
# ```python
# def __init__(self, transform, mode, batch_size, vocab_threshold, vocab_file, start_word,
#         end_word, unk_word, annotations_file, vocab_from_file, img_folder):
#         ...
#         self.vocab = Vocabulary(vocab_threshold, vocab_file, start_word,
#             end_word, unk_word, annotations_file, vocab_from_file)
#         ...
# ```
# From the code snippet above, you can see that `data_loader.dataset.vocab` is an instance of the `Vocabulary` class from **vocabulary.py**.  Take the time now to verify this for yourself by looking at the full code in **data_loader.py**.
#
# We use this instance to pre-process the COCO captions (from the `__getitem__` method in the `CoCoDataset` class):
#
# ```python
# # Convert caption to tensor of word ids.
# tokens = nltk.tokenize.word_tokenize(str(caption).lower())   # line 1
# caption = []                                                 # line 2
# caption.append(self.vocab(self.vocab.start_word))            # line 3
# caption.extend([self.vocab(token) for token in tokens])      # line 4
# caption.append(self.vocab(self.vocab.end_word))              # line 5
# caption = torch.Tensor(caption).long()                       # line 6
# ```
#
# As you will see soon, this code converts any string-valued caption to a list of integers, before casting it to a PyTorch tensor.  To see how this code works, we'll apply it to the sample caption in the next code cell.

# %%
sample_caption = 'A person doing a trick on a rail while riding a skateboard.'

# %% [markdown]
# In **`line 1`** of the code snippet, every letter in the caption is converted to lowercase, and the [`nltk.tokenize.word_tokenize`](http://www.nltk.org/) function is used to obtain a list of string-valued tokens.  Run the next code cell to visualize the effect on `sample_caption`.

# %%
import nltk

sample_tokens = nltk.tokenize.word_tokenize(str(sample_caption).lower())
print(sample_tokens)
# Out:
# ['a', 'person', 'doing', 'a', 'trick', 'on', 'a', 'rail', 'while', 'riding', 'a', 'skateboard', '.']

# %% [markdown]
# In **`line 2`** and **`line 3`** we initialize an empty list and append an integer to mark the start of a caption.  The [paper](https://arxiv.org/pdf/1411.4555.pdf) that you are encouraged to implement uses a special start word (and a special end word, which we'll examine below) to mark the beginning (and end) of a caption.
#
# This special start word (`"<start>"`) is decided when instantiating the data loader and is passed as a parameter (`start_word`).  You are **required** to keep this parameter at its default value (`start_word="<start>"`).
#
# As you will see below, the integer `0` is always used to mark the start of a caption.

# %%
sample_caption = []

start_word = data_loader.dataset.vocab.start_word
print('Special start word:', start_word)
sample_caption.append(data_loader.dataset.vocab(start_word))
print(sample_caption)
# Out:
# Special start word: <start>
# [0]

# %% [markdown]
# In **`line 4`**, we continue the list by adding integers that correspond to each of the tokens in the caption.

# %%
sample_caption.extend([data_loader.dataset.vocab(token) for token in sample_tokens])
print(sample_caption)
# Out:
# [0, 3, 98, 754, 3, 396, 39, 3, 1010, 207, 139, 3, 753, 18]

# %% [markdown]
# In **`line 5`**, we append a final integer to mark the end of the caption.
#
# Identical to the case of the special start word (above), the special end word (`"<end>"`) is decided when instantiating the data loader and is passed as a parameter (`end_word`).  You are **required** to keep this parameter at its default value (`end_word="<end>"`).
#
# As you will see below, the integer `1` is always used to  mark the end of a caption.

# %%
end_word = data_loader.dataset.vocab.end_word
print('Special end word:', end_word)

sample_caption.append(data_loader.dataset.vocab(end_word))
print(sample_caption)
# Out:
# Special end word: <end>
# [0, 3, 98, 754, 3, 396, 39, 3, 1010, 207, 139, 3, 753, 18, 1]

# %% [markdown]
# Finally, in **`line 6`**, we convert the list of integers to a PyTorch tensor and cast it to [long type](http://pytorch.org/docs/master/tensors.html#torch.Tensor.long).  You can read more about the different types of PyTorch tensors on the [website](http://pytorch.org/docs/master/tensors.html).

# %%
import torch

sample_caption = torch.Tensor(sample_caption).long()
print(sample_caption)
# Out:
# tensor([   0,    3,   98,  754,    3,  396,   39,    3, 1010,  207,  139,    3,
#          753,   18,    1])

# %% [markdown]
# And that's it!  In summary, any caption is converted to a list of tokens, with _special_ start and end tokens marking the beginning and end of the sentence:
# ```
# [<start>, 'a', 'person', 'doing', 'a', 'trick', 'while', 'riding', 'a', 'skateboard', '.', <end>]
# ```
# This list of tokens is then turned into a list of integers, where every distinct word in the vocabulary has an associated integer value:
# ```
# [0, 3, 98, 754, 3, 396, 207, 139, 3, 753, 18, 1]
# ```
# Finally, this list is converted to a PyTorch tensor.  All of the captions in the COCO dataset are pre-processed using this same procedure from **`lines 1-6`** described above.
#
# As you saw, in order to convert a token to its corresponding integer, we call `data_loader.dataset.vocab` as a function.  The details of how this call works can be explored in the `__call__` method in the `Vocabulary` class in **vocabulary.py**.
#
# ```python
# def __call__(self, word):
#     if not word in self.word2idx:
#         return self.word2idx[self.unk_word]
#     return self.word2idx[word]
# ```
#
# The `word2idx` instance variable is a Python [dictionary](https://docs.python.org/3/tutorial/datastructures.html#dictionaries) that is indexed by string-valued keys (mostly tokens obtained from training captions).  For each key, the corresponding value is the integer that the token is mapped to in the pre-processing step.
#
# Use the code cell below to view a subset of this dictionary.

# %%
# Preview the word2idx dictionary.
dict(list(data_loader.dataset.vocab.word2idx.items())[:10])
# Out:
# {'<start>': 0,
#  '<end>': 1,
#  '<unk>': 2,
#  'a': 3,
#  'very': 4,
#  'clean': 5,
#  'and': 6,
#  'well': 7,
#  'decorated': 8,
#  'empty': 9}

# %% [markdown]
# We also print the total number of keys.

# %%
# Print the total number of keys in the word2idx dictionary.
print('Total number of tokens in vocabulary:', len(data_loader.dataset.vocab))
# Out:
# Total number of tokens in vocabulary: 8852

# %% [markdown]
# As you will see if you examine the code in **vocabulary.py**, the `word2idx` dictionary is created by looping over the captions in the training dataset.  If a token appears no less than `vocab_threshold` times in the training set, then it is added as a key to the dictionary and assigned a corresponding unique integer.  You will have the option later to amend the `vocab_threshold` argument when instantiating your data loader.  Note that in general, **smaller** values for `vocab_threshold` yield a **larger** number of tokens in the vocabulary.  You are encouraged to check this for yourself in the next code cell by decreasing the value of `vocab_threshold` before creating a new data loader.

# %%
# Modify the minimum word count threshold.
vocab_threshold = 40

# Obtain the data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=False)
# Out:
# loading annotations into memory...
# Done (t=1.08s)
# creating index...
# index created!
# [0/414113] Tokenizing captions...
# [100000/414113] Tokenizing captions...
# [200000/414113] Tokenizing captions...
# [300000/414113] Tokenizing captions...
# [400000/414113] Tokenizing captions...
# loading annotations into memory...
# Done (t=0.76s)
# creating index...
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [00:56<00:00, 7355.44it/s]

# %%
# Print the total number of keys in the word2idx dictionary.
print('Total number of tokens in vocabulary:', len(data_loader.dataset.vocab))
# Out:
# Total number of tokens in vocabulary: 3185

# %% [markdown]
# There are also a few special keys in the `word2idx` dictionary.  You are already familiar with the special start word (`"<start>"`) and special end word (`"<end>"`).  There is one more special token, corresponding to unknown words (`"<unk>"`).  All tokens that don't appear anywhere in the `word2idx` dictionary are considered unknown words.  In the pre-processing step, any unknown tokens are mapped to the integer `2`.

# %%
unk_word = data_loader.dataset.vocab.unk_word
print('Special unknown word:', unk_word)

print('All unknown words are mapped to this integer:', data_loader.dataset.vocab(unk_word))
# Out:
# Special unknown word: <unk>
# All unknown words are mapped to this integer: 2

# %% [markdown]
# Check this for yourself below, by pre-processing the provided nonsense words that never appear in the training captions.

# %%
print(data_loader.dataset.vocab('move'))
print(data_loader.dataset.vocab('ieowoqjf'))
# Out:
# 1477
# 2

# %% [markdown]
# The final thing to mention is the `vocab_from_file` argument that is supplied when creating a data loader.  To understand this argument, note that when you create a new data loader, the vocabulary (`data_loader.dataset.vocab`) is saved as a [pickle](https://docs.python.org/3/library/pickle.html) file in the project folder, with filename `vocab.pkl`.
#
# If you are still tweaking the value of the `vocab_threshold` argument, you **must** set `vocab_from_file=False` to have your changes take effect.
#
# But once you are happy with the value that you have chosen for the `vocab_threshold` argument, you need only run the data loader *one more time* with your chosen `vocab_threshold` to save the new vocabulary to file.  Then, you can henceforth set `vocab_from_file=True` to load the vocabulary from file and speed the instantiation of the data loader.  Note that building the vocabulary from scratch is the most time-consuming part of instantiating the data loader, and so you are strongly encouraged to set `vocab_from_file=True` as soon as you are able.
#
# Note that if `vocab_from_file=True`, then any supplied argument for `vocab_threshold` when instantiating the data loader is completely ignored.

# %%
# Obtain the data loader (from file). Note that it runs much faster than before!
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_from_file=True)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=1.01s)
# creating index...
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [00:57<00:00, 7257.76it/s]

# %% [markdown]
# In the next section, you will learn how to use the data loader to obtain batches of training data.

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Use the Data Loader to Obtain Batches
#
# The captions in the dataset vary greatly in length.  You can see this by examining `data_loader.dataset.caption_lengths`, a Python list with one entry for each training caption (where the value stores the length of the corresponding caption).
#
# In the code cell below, we use this list to print the total number of captions in the training data with each length.  As you will see below, the majority of captions have length 10.  Likewise, very short and very long captions are quite rare.

# %%
from collections import Counter

# Tally the total number of training captions with each length.
counter = Counter(data_loader.dataset.caption_lengths)
lengths = sorted(counter.items(), key=lambda pair: pair[1], reverse=True)
for value, count in lengths:
    print('value: %2d --- count: %5d' % (value, count))
# Out:
# value: 10 --- count: 86302
# value: 11 --- count: 79971
# value:  9 --- count: 71920
# value: 12 --- count: 57653
# value: 13 --- count: 37668
# value: 14 --- count: 22342
# value:  8 --- count: 20742
# value: 15 --- count: 12839
# value: 16 --- count:  7736
# value: 17 --- count:  4845
# value: 18 --- count:  3101
# value: 19 --- count:  2017
# value:  7 --- count:  1594
# value: 20 --- count:  1453
# value: 21 --- count:   997
# value: 22 --- count:   683
# value: 23 --- count:   534
# value: 24 --- count:   384
# value: 25 --- count:   277
# value: 26 --- count:   214
# value: 27 --- count:   160
# value: 28 --- count:   114
# value: 29 --- count:    87
# value: 30 --- count:    58
# value: 31 --- count:    49
# value: 32 --- count:    44
# value: 34 --- count:    40
# value: 37 --- count:    32
# value: 35 --- count:    31
# value: 33 --- count:    30
# value: 36 --- count:    26
# value: 38 --- count:    18
# value: 39 --- count:    18
# value: 43 --- count:    16
# value: 44 --- count:    16
# value: 48 --- count:    12
# value: 45 --- count:    11
# value: 42 --- count:    10
# value: 40 --- count:     9
# value: 49 --- count:     9
# value: 46 --- count:     9
# value: 47 --- count:     7
# value: 50 --- count:     6
# value: 51 --- count:     6
# value: 41 --- count:     6
# value: 52 --- count:     5
# value: 54 --- count:     3
# value: 56 --- count:     2
# value:  6 --- count:     2
# value: 53 --- count:     2
# value: 55 --- count:     2
# value: 57 --- count:     1

# %% [markdown]
# To generate batches of training data, we begin by first sampling a caption length (where the probability that any length is drawn is proportional to the number of captions with that length in the dataset).  Then, we retrieve a batch of size `batch_size` of image-caption pairs, where all captions have the sampled length.  This approach for assembling batches matches the procedure in [this paper](https://arxiv.org/pdf/1502.03044.pdf) and has been shown to be computationally efficient without degrading performance.
#
# Run the code cell below to generate a batch.  The `get_train_indices` method in the `CoCoDataset` class first samples a caption length, and then samples `batch_size` indices corresponding to training data points with captions of that length.  These indices are stored below in `indices`.
#
# These indices are supplied to the data loader, which then is used to retrieve the corresponding data points.  The pre-processed images and captions in the batch are stored in `images` and `captions`.

# %%
import numpy as np
import torch.utils.data as data

# Randomly sample a caption length, and sample indices with that length.
indices = data_loader.dataset.get_train_indices()
print('sampled indices:', indices)

# Create and assign a batch sampler to retrieve a batch with the sampled indices.
new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
data_loader.batch_sampler.sampler = new_sampler
#!rm -r /coco/train2014
#!unzip /coco/train2014.zip -d /coco
# !ls -l /coco/train2014/
# Obtain the batch.
images, captions = next(iter(data_loader))

print('images.shape:', images.shape)
print('captions.shape:', captions.shape)

# (Optional) Uncomment the lines of code below to print the pre-processed images and captions.
# print('images:', images)
# print('captions:', captions)
# Out:
# Streaming output truncated to the last 5000 lines.
# -rw-rw-r-- 1 root root  107719 Aug 16  2014 COCO_train2014_000000547315.jpg
# -rw-rw-r-- 1 root root  209881 Aug 16  2014 COCO_train2014_000000547318.jpg
# -rw-rw-r-- 1 root root   85856 Aug 16  2014 COCO_train2014_000000547348.jpg
# -rw-rw-r-- 1 root root  182051 Aug 16  2014 COCO_train2014_000000547351.jpg
# -rw-rw-r-- 1 root root  201119 Aug 16  2014 COCO_train2014_000000547352.jpg
# -rw-rw-r-- 1 root root  100588 Aug 16  2014 COCO_train2014_000000547363.jpg
# -rw-rw-r-- 1 root root  154580 Aug 16  2014 COCO_train2014_000000547367.jpg
# -rw-rw-r-- 1 root root  202263 Aug 16  2014 COCO_train2014_000000547369.jpg
# -rw-rw-r-- 1 root root  139899 Aug 16  2014 COCO_train2014_000000547378.jpg
# -rw-rw-r-- 1 root root  337827 Aug 16  2014 COCO_train2014_000000547387.jpg
# -rw-rw-r-- 1 root root  220103 Aug 16  2014 COCO_train2014_000000547388.jpg
# -rw-rw-r-- 1 root root  340520 Aug 16  2014 COCO_train2014_000000547391.jpg
# -rw-rw-r-- 1 root root  119926 Aug 16  2014 COCO_train2014_000000547411.jpg
# -rw-rw-r-- 1 root root   93260 Aug 16  2014 COCO_train2014_000000547417.jpg
# -rw-rw-r-- 1 root root  188321 Aug 16  2014 COCO_train2014_000000547419.jpg
# -rw-rw-r-- 1 root root  169760 Aug 16  2014 COCO_train2014_000000547422.jpg
# -rw-rw-r-- 1 root root  122333 Aug 16  2014 COCO_train2014_000000547428.jpg
# -rw-rw-r-- 1 root root  117222 Aug 16  2014 COCO_train2014_000000547439.jpg
# -rw-rw-r-- 1 root root   95846 Aug 16  2014 COCO_train2014_000000547448.jpg
# -rw-rw-r-- 1 root root  290613 Aug 16  2014 COCO_train2014_000000547449.jpg
# -rw-rw-r-- 1 root root   69983 Aug 16  2014 COCO_train2014_000000547450.jpg
# -rw-rw-r-- 1 root root  200111 Aug 16  2014 COCO_train2014_000000547459.jpg
# -rw-rw-r-- 1 root root  263242 Aug 16  2014 COCO_train2014_000000547460.jpg
# -rw-rw-r-- 1 root root  203621 Aug 16  2014 COCO_train2014_000000547465.jpg
# -rw-rw-r-- 1 root root   87901 Aug 16  2014 COCO_train2014_000000547470.jpg
# -rw-rw-r-- 1 root root  144420 Aug 16  2014 COCO_train2014_000000547471.jpg
# -rw-rw-r-- 1 root root  187825 Aug 16  2014 COCO_train2014_000000547475.jpg
# -rw-rw-r-- 1 root root   57685 Aug 16  2014 COCO_train2014_000000547485.jpg
# -rw-rw-r-- 1 root root  300634 Aug 16  2014 COCO_train2014_000000547498.jpg
# -rw-rw-r-- 1 root root  128807 Aug 16  2014 COCO_train2014_000000547503.jpg
# -rw-rw-r-- 1 root root  239968 Aug 16  2014 COCO_train2014_000000547509.jpg
# -rw-rw-r-- 1 root root  134784 Aug 16  2014 COCO_train2014_000000547513.jpg
# -rw-rw-r-- 1 root root  100074 Aug 16  2014 COCO_train2014_000000547514.jpg
# -rw-rw-r-- 1 root root  317219 Aug 16  2014 COCO_train2014_000000547524.jpg
# -rw-rw-r-- 1 root root  183924 Aug 16  2014 COCO_train2014_000000547528.jpg
# -rw-rw-r-- 1 root root  158324 Aug 16  2014 COCO_train2014_000000547532.jpg
# -rw-rw-r-- 1 root root  227444 Aug 16  2014 COCO_train2014_000000547533.jpg
# -rw-rw-r-- 1 root root  128180 Aug 16  2014 COCO_train2014_000000547542.jpg
# -rw-rw-r-- 1 root root  271029 Aug 16  2014 COCO_train2014_000000547555.jpg
# -rw-rw-r-- 1 root root  142491 Aug 16  2014 COCO_train2014_000000547592.jpg
# -rw-rw-r-- 1 root root  244015 Aug 16  2014 COCO_train2014_000000547594.jpg
# -rw-rw-r-- 1 root root  157342 Aug 16  2014 COCO_train2014_000000547614.jpg
# -rw-rw-r-- 1 root root  146358 Aug 16  2014 COCO_train2014_000000547618.jpg
# -rw-rw-r-- 1 root root  153240 Aug 16  2014 COCO_train2014_000000547633.jpg
# -rw-rw-r-- 1 root root  140615 Aug 16  2014 COCO_train2014_000000547635.jpg
# -rw-rw-r-- 1 root root  157351 Aug 16  2014 COCO_train2014_000000547636.jpg
# -rw-rw-r-- 1 root root  230948 Aug 16  2014 COCO_train2014_000000547637.jpg
# -rw-rw-r-- 1 root root  173864 Aug 16  2014 COCO_train2014_000000547643.jpg
# -rw-rw-r-- 1 root root  174853 Aug 16  2014 COCO_train2014_000000547644.jpg
# -rw-rw-r-- 1 root root  140849 Aug 16  2014 COCO_train2014_000000547662.jpg
# -rw-rw-r-- 1 root root   77612 Aug 16  2014 COCO_train2014_000000547672.jpg
# -rw-rw-r-- 1 root root  226258 Aug 16  2014 COCO_train2014_000000547675.jpg
# -rw-rw-r-- 1 root root   83597 Aug 16  2014 COCO_train2014_000000547693.jpg
# -rw-rw-r-- 1 root root   97772 Aug 16  2014 COCO_train2014_000000547703.jpg
# -rw-rw-r-- 1 root root   38662 Aug 16  2014 COCO_train2014_000000547722.jpg
# -rw-rw-r-- 1 root root   77181 Aug 16  2014 COCO_train2014_000000547726.jpg
# -rw-rw-r-- 1 root root  137521 Aug 16  2014 COCO_train2014_000000547730.jpg
# -rw-rw-r-- 1 root root  108365 Aug 16  2014 COCO_train2014_000000547742.jpg
# -rw-rw-r-- 1 root root  210208 Aug 16  2014 COCO_train2014_000000547743.jpg
# -rw-rw-r-- 1 root root  150486 Aug 16  2014 COCO_train2014_000000547745.jpg
# -rw-rw-r-- 1 root root  114670 Aug 16  2014 COCO_train2014_000000547752.jpg
# -rw-rw-r-- 1 root root  176314 Aug 16  2014 COCO_train2014_000000547764.jpg
# -rw-rw-r-- 1 root root   93553 Aug 16  2014 COCO_train2014_000000547767.jpg
# -rw-rw-r-- 1 root root  290913 Aug 16  2014 COCO_train2014_000000547768.jpg
# -rw-rw-r-- 1 root root  157230 Aug 16  2014 COCO_train2014_000000547769.jpg
# -rw-rw-r-- 1 root root  240973 Aug 16  2014 COCO_train2014_000000547770.jpg
# -rw-rw-r-- 1 root root  189547 Aug 16  2014 COCO_train2014_000000547774.jpg
# -rw-rw-r-- 1 root root   95571 Aug 16  2014 COCO_train2014_000000547777.jpg
# -rw-rw-r-- 1 root root  153654 Aug 16  2014 COCO_train2014_000000547794.jpg
# -rw-rw-r-- 1 root root   55103 Aug 16  2014 COCO_train2014_000000547795.jpg
# -rw-rw-r-- 1 root root  207628 Aug 16  2014 COCO_train2014_000000547796.jpg
# -rw-rw-r-- 1 root root  226447 Aug 16  2014 COCO_train2014_000000547797.jpg
# -rw-rw-r-- 1 root root  253133 Aug 16  2014 COCO_train2014_000000547807.jpg
# -rw-rw-r-- 1 root root   92796 Aug 16  2014 COCO_train2014_000000547808.jpg
# -rw-rw-r-- 1 root root  150293 Aug 16  2014 COCO_train2014_000000547817.jpg
# -rw-rw-r-- 1 root root  110929 Aug 16  2014 COCO_train2014_000000547827.jpg
# -rw-rw-r-- 1 root root  146125 Aug 16  2014 COCO_train2014_000000547830.jpg
# -rw-rw-r-- 1 root root  165385 Aug 16  2014 COCO_train2014_000000547837.jpg
# -rw-rw-r-- 1 root root  219981 Aug 16  2014 COCO_train2014_000000547845.jpg
# -rw-rw-r-- 1 root root  183036 Aug 16  2014 COCO_train2014_000000547846.jpg
# -rw-rw-r-- 1 root root  218173 Aug 16  2014 COCO_train2014_000000547859.jpg
# -rw-rw-r-- 1 root root  259963 Aug 16  2014 COCO_train2014_000000547863.jpg
# -rw-rw-r-- 1 root root  238768 Aug 16  2014 COCO_train2014_000000547869.jpg
# -rw-rw-r-- 1 root root  280124 Aug 16  2014 COCO_train2014_000000547879.jpg
# -rw-rw-r-- 1 root root  104179 Aug 16  2014 COCO_train2014_000000547896.jpg
# -rw-rw-r-- 1 root root  189089 Aug 16  2014 COCO_train2014_000000547938.jpg
# -rw-rw-r-- 1 root root  273566 Aug 16  2014 COCO_train2014_000000547944.jpg
# -rw-rw-r-- 1 root root  109521 Aug 16  2014 COCO_train2014_000000547960.jpg
# -rw-rw-r-- 1 root root  299469 Aug 16  2014 COCO_train2014_000000547966.jpg
# -rw-rw-r-- 1 root root  317268 Aug 16  2014 COCO_train2014_000000547974.jpg
# -rw-rw-r-- 1 root root  195048 Aug 16  2014 COCO_train2014_000000547979.jpg
# -rw-rw-r-- 1 root root  107124 Aug 16  2014 COCO_train2014_000000547985.jpg
# -rw-rw-r-- 1 root root  137750 Aug 16  2014 COCO_train2014_000000547999.jpg
# -rw-rw-r-- 1 root root  215428 Aug 16  2014 COCO_train2014_000000548010.jpg
# -rw-rw-r-- 1 root root  103045 Aug 16  2014 COCO_train2014_000000548013.jpg
# -rw-rw-r-- 1 root root  202807 Aug 16  2014 COCO_train2014_000000548020.jpg
# -rw-rw-r-- 1 root root  112029 Aug 16  2014 COCO_train2014_000000548029.jpg
# -rw-rw-r-- 1 root root  171737 Aug 16  2014 COCO_train2014_000000548039.jpg
# -rw-rw-r-- 1 root root  102208 Aug 16  2014 COCO_train2014_000000548053.jpg
# -rw-rw-r-- 1 root root  167313 Aug 16  2014 COCO_train2014_000000548061.jpg
# -rw-rw-r-- 1 root root  336660 Aug 16  2014 COCO_train2014_000000548067.jpg
# -rw-rw-r-- 1 root root  101094 Aug 16  2014 COCO_train2014_000000548088.jpg
# -rw-rw-r-- 1 root root  161491 Aug 16  2014 COCO_train2014_000000548107.jpg
# -rw-rw-r-- 1 root root  282200 Aug 16  2014 COCO_train2014_000000548109.jpg
# -rw-rw-r-- 1 root root  131901 Aug 16  2014 COCO_train2014_000000548118.jpg
# -rw-rw-r-- 1 root root  279753 Aug 16  2014 COCO_train2014_000000548136.jpg
# -rw-rw-r-- 1 root root  150541 Aug 16  2014 COCO_train2014_000000548141.jpg
# -rw-rw-r-- 1 root root  135802 Aug 16  2014 COCO_train2014_000000548153.jpg
# -rw-rw-r-- 1 root root   75163 Aug 16  2014 COCO_train2014_000000548167.jpg
# -rw-rw-r-- 1 root root  191843 Aug 16  2014 COCO_train2014_000000548168.jpg
# -rw-rw-r-- 1 root root  156842 Aug 16  2014 COCO_train2014_000000548169.jpg
# -rw-rw-r-- 1 root root  157125 Aug 16  2014 COCO_train2014_000000548171.jpg
# -rw-rw-r-- 1 root root  117652 Aug 16  2014 COCO_train2014_000000548172.jpg
# -rw-rw-r-- 1 root root  132918 Aug 16  2014 COCO_train2014_000000548175.jpg
# -rw-rw-r-- 1 root root  106488 Aug 16  2014 COCO_train2014_000000548177.jpg
# -rw-rw-r-- 1 root root  230992 Aug 16  2014 COCO_train2014_000000548183.jpg
# -rw-rw-r-- 1 root root  185877 Aug 16  2014 COCO_train2014_000000548184.jpg
# -rw-rw-r-- 1 root root  110459 Aug 16  2014 COCO_train2014_000000548186.jpg
# -rw-rw-r-- 1 root root  136967 Aug 16  2014 COCO_train2014_000000548198.jpg
# -rw-rw-r-- 1 root root   98686 Aug 16  2014 COCO_train2014_000000548215.jpg
# -rw-rw-r-- 1 root root  124769 Aug 16  2014 COCO_train2014_000000548218.jpg
# -rw-rw-r-- 1 root root  117209 Aug 16  2014 COCO_train2014_000000548224.jpg
# -rw-rw-r-- 1 root root   91142 Aug 16  2014 COCO_train2014_000000548240.jpg
# -rw-rw-r-- 1 root root  187677 Aug 16  2014 COCO_train2014_000000548251.jpg
# -rw-rw-r-- 1 root root  163626 Aug 16  2014 COCO_train2014_000000548253.jpg
# -rw-rw-r-- 1 root root   71332 Aug 16  2014 COCO_train2014_000000548273.jpg
# -rw-rw-r-- 1 root root  155099 Aug 16  2014 COCO_train2014_000000548278.jpg
# -rw-rw-r-- 1 root root  282591 Aug 16  2014 COCO_train2014_000000548291.jpg
# -rw-rw-r-- 1 root root  160132 Aug 16  2014 COCO_train2014_000000548293.jpg
# -rw-rw-r-- 1 root root   88089 Aug 16  2014 COCO_train2014_000000548318.jpg
# -rw-rw-r-- 1 root root   88270 Aug 16  2014 COCO_train2014_000000548322.jpg
# -rw-rw-r-- 1 root root  167509 Aug 16  2014 COCO_train2014_000000548323.jpg
# -rw-rw-r-- 1 root root   89332 Aug 16  2014 COCO_train2014_000000548351.jpg
# -rw-rw-r-- 1 root root  135519 Aug 16  2014 COCO_train2014_000000548357.jpg
# -rw-rw-r-- 1 root root  189184 Aug 16  2014 COCO_train2014_000000548362.jpg
# -rw-rw-r-- 1 root root  142545 Aug 16  2014 COCO_train2014_000000548375.jpg
# -rw-rw-r-- 1 root root  255317 Aug 16  2014 COCO_train2014_000000548377.jpg
# -rw-rw-r-- 1 root root  195638 Aug 16  2014 COCO_train2014_000000548384.jpg
# -rw-rw-r-- 1 root root  157292 Aug 16  2014 COCO_train2014_000000548388.jpg
# -rw-rw-r-- 1 root root  135517 Aug 16  2014 COCO_train2014_000000548390.jpg
# -rw-rw-r-- 1 root root  114753 Aug 16  2014 COCO_train2014_000000548391.jpg
# -rw-rw-r-- 1 root root  110505 Aug 16  2014 COCO_train2014_000000548393.jpg
# -rw-rw-r-- 1 root root  117924 Aug 16  2014 COCO_train2014_000000548416.jpg
# -rw-rw-r-- 1 root root  167797 Aug 16  2014 COCO_train2014_000000548418.jpg
# -rw-rw-r-- 1 root root  217060 Aug 16  2014 COCO_train2014_000000548428.jpg
# -rw-rw-r-- 1 root root   69966 Aug 16  2014 COCO_train2014_000000548451.jpg
# -rw-rw-r-- 1 root root   89849 Aug 16  2014 COCO_train2014_000000548452.jpg
# -rw-rw-r-- 1 root root  144317 Aug 16  2014 COCO_train2014_000000548471.jpg
# -rw-rw-r-- 1 root root   81256 Aug 16  2014 COCO_train2014_000000548511.jpg
# -rw-rw-r-- 1 root root  183874 Aug 16  2014 COCO_train2014_000000548512.jpg
# -rw-rw-r-- 1 root root   41851 Aug 16  2014 COCO_train2014_000000548515.jpg
# -rw-rw-r-- 1 root root  156525 Aug 16  2014 COCO_train2014_000000548532.jpg
# -rw-rw-r-- 1 root root  199903 Aug 16  2014 COCO_train2014_000000548537.jpg
# -rw-rw-r-- 1 root root  152667 Aug 16  2014 COCO_train2014_000000548544.jpg
# -rw-rw-r-- 1 root root  181449 Aug 16  2014 COCO_train2014_000000548545.jpg
# -rw-rw-r-- 1 root root  160911 Aug 16  2014 COCO_train2014_000000548546.jpg
# -rw-rw-r-- 1 root root  135179 Aug 16  2014 COCO_train2014_000000548548.jpg
# -rw-rw-r-- 1 root root  289371 Aug 16  2014 COCO_train2014_000000548559.jpg
# -rw-rw-r-- 1 root root   98718 Aug 16  2014 COCO_train2014_000000548562.jpg
# -rw-rw-r-- 1 root root  133122 Aug 16  2014 COCO_train2014_000000548564.jpg
# -rw-rw-r-- 1 root root  157655 Aug 16  2014 COCO_train2014_000000548565.jpg
# -rw-rw-r-- 1 root root  151990 Aug 16  2014 COCO_train2014_000000548575.jpg
# -rw-rw-r-- 1 root root   88702 Aug 16  2014 COCO_train2014_000000548583.jpg
# -rw-rw-r-- 1 root root  124470 Aug 16  2014 COCO_train2014_000000548593.jpg
# -rw-rw-r-- 1 root root  245281 Aug 16  2014 COCO_train2014_000000548597.jpg
# -rw-rw-r-- 1 root root  185535 Aug 16  2014 COCO_train2014_000000548608.jpg
# -rw-rw-r-- 1 root root  213892 Aug 16  2014 COCO_train2014_000000548616.jpg
# -rw-rw-r-- 1 root root  219907 Aug 16  2014 COCO_train2014_000000548619.jpg
# -rw-rw-r-- 1 root root  131157 Aug 16  2014 COCO_train2014_000000548636.jpg
# -rw-rw-r-- 1 root root  119903 Aug 16  2014 COCO_train2014_000000548644.jpg
# -rw-rw-r-- 1 root root  243490 Aug 16  2014 COCO_train2014_000000548647.jpg
# -rw-rw-r-- 1 root root   82718 Aug 16  2014 COCO_train2014_000000548652.jpg
# -rw-rw-r-- 1 root root   91660 Aug 16  2014 COCO_train2014_000000548661.jpg
# -rw-rw-r-- 1 root root  215508 Aug 16  2014 COCO_train2014_000000548662.jpg
# -rw-rw-r-- 1 root root  153168 Aug 16  2014 COCO_train2014_000000548672.jpg
# -rw-rw-r-- 1 root root   88198 Aug 16  2014 COCO_train2014_000000548689.jpg
# -rw-rw-r-- 1 root root  115491 Aug 16  2014 COCO_train2014_000000548690.jpg
# -rw-rw-r-- 1 root root  226153 Aug 16  2014 COCO_train2014_000000548698.jpg
# -rw-rw-r-- 1 root root  104928 Aug 16  2014 COCO_train2014_000000548702.jpg
# -rw-rw-r-- 1 root root  132737 Aug 16  2014 COCO_train2014_000000548704.jpg
# -rw-rw-r-- 1 root root  168977 Aug 16  2014 COCO_train2014_000000548711.jpg
# -rw-rw-r-- 1 root root  177675 Aug 16  2014 COCO_train2014_000000548723.jpg
# -rw-rw-r-- 1 root root  181749 Aug 16  2014 COCO_train2014_000000548725.jpg
# -rw-rw-r-- 1 root root  254213 Aug 16  2014 COCO_train2014_000000548726.jpg
# -rw-rw-r-- 1 root root  101800 Aug 16  2014 COCO_train2014_000000548731.jpg
# -rw-rw-r-- 1 root root  122837 Aug 16  2014 COCO_train2014_000000548732.jpg
# -rw-rw-r-- 1 root root  133222 Aug 16  2014 COCO_train2014_000000548734.jpg
# -rw-rw-r-- 1 root root  104510 Aug 16  2014 COCO_train2014_000000548742.jpg
# -rw-rw-r-- 1 root root  168286 Aug 16  2014 COCO_train2014_000000548755.jpg
# -rw-rw-r-- 1 root root  101412 Aug 16  2014 COCO_train2014_000000548768.jpg
# -rw-rw-r-- 1 root root   65198 Aug 16  2014 COCO_train2014_000000548772.jpg
# -rw-rw-r-- 1 root root   90194 Aug 16  2014 COCO_train2014_000000548773.jpg
# -rw-rw-r-- 1 root root  155678 Aug 16  2014 COCO_train2014_000000548786.jpg
# -rw-rw-r-- 1 root root  137207 Aug 16  2014 COCO_train2014_000000548791.jpg
# -rw-rw-r-- 1 root root   67040 Aug 16  2014 COCO_train2014_000000548792.jpg
# -rw-rw-r-- 1 root root  104380 Aug 16  2014 COCO_train2014_000000548802.jpg
# -rw-rw-r-- 1 root root  261193 Aug 16  2014 COCO_train2014_000000548821.jpg
# -rw-rw-r-- 1 root root  254097 Aug 16  2014 COCO_train2014_000000548822.jpg
# -rw-rw-r-- 1 root root  179271 Aug 16  2014 COCO_train2014_000000548824.jpg
# -rw-rw-r-- 1 root root  106659 Aug 16  2014 COCO_train2014_000000548834.jpg
# -rw-rw-r-- 1 root root   94241 Aug 16  2014 COCO_train2014_000000548835.jpg
# -rw-rw-r-- 1 root root  177291 Aug 16  2014 COCO_train2014_000000548836.jpg
# -rw-rw-r-- 1 root root  151363 Aug 16  2014 COCO_train2014_000000548845.jpg
# -rw-rw-r-- 1 root root  184784 Aug 16  2014 COCO_train2014_000000548858.jpg
# -rw-rw-r-- 1 root root  145262 Aug 16  2014 COCO_train2014_000000548861.jpg
# -rw-rw-r-- 1 root root  306415 Aug 16  2014 COCO_train2014_000000548863.jpg
# -rw-rw-r-- 1 root root  201049 Aug 16  2014 COCO_train2014_000000548874.jpg
# -rw-rw-r-- 1 root root  329257 Aug 16  2014 COCO_train2014_000000548875.jpg
# -rw-rw-r-- 1 root root  175956 Aug 16  2014 COCO_train2014_000000548889.jpg
# -rw-rw-r-- 1 root root  155528 Aug 16  2014 COCO_train2014_000000548893.jpg
# -rw-rw-r-- 1 root root   69909 Aug 16  2014 COCO_train2014_000000548905.jpg
# -rw-rw-r-- 1 root root  151483 Aug 16  2014 COCO_train2014_000000548906.jpg
# -rw-rw-r-- 1 root root   46406 Aug 16  2014 COCO_train2014_000000548912.jpg
# -rw-rw-r-- 1 root root   55525 Aug 16  2014 COCO_train2014_000000548913.jpg
# -rw-rw-r-- 1 root root  291032 Aug 16  2014 COCO_train2014_000000548915.jpg
# -rw-rw-r-- 1 root root   57022 Aug 16  2014 COCO_train2014_000000548926.jpg
# -rw-rw-r-- 1 root root  112515 Aug 16  2014 COCO_train2014_000000548933.jpg
# -rw-rw-r-- 1 root root  174416 Aug 16  2014 COCO_train2014_000000548935.jpg
# -rw-rw-r-- 1 root root  137277 Aug 16  2014 COCO_train2014_000000548936.jpg
# -rw-rw-r-- 1 root root  166975 Aug 16  2014 COCO_train2014_000000548943.jpg
# -rw-rw-r-- 1 root root  149941 Aug 16  2014 COCO_train2014_000000548951.jpg
# -rw-rw-r-- 1 root root  175893 Aug 16  2014 COCO_train2014_000000548953.jpg
# -rw-rw-r-- 1 root root  221314 Aug 16  2014 COCO_train2014_000000548958.jpg
# -rw-rw-r-- 1 root root   95471 Aug 16  2014 COCO_train2014_000000548964.jpg
# -rw-rw-r-- 1 root root  184414 Aug 16  2014 COCO_train2014_000000548965.jpg
# -rw-rw-r-- 1 root root  119416 Aug 16  2014 COCO_train2014_000000548971.jpg
# -rw-rw-r-- 1 root root  103843 Aug 16  2014 COCO_train2014_000000548974.jpg
# -rw-rw-r-- 1 root root  112957 Aug 16  2014 COCO_train2014_000000548976.jpg
# -rw-rw-r-- 1 root root  315371 Aug 16  2014 COCO_train2014_000000548979.jpg
# -rw-rw-r-- 1 root root  176315 Aug 16  2014 COCO_train2014_000000549002.jpg
# -rw-rw-r-- 1 root root  204816 Aug 16  2014 COCO_train2014_000000549003.jpg
# -rw-rw-r-- 1 root root  175607 Aug 16  2014 COCO_train2014_000000549011.jpg
# -rw-rw-r-- 1 root root  170683 Aug 16  2014 COCO_train2014_000000549017.jpg
# -rw-rw-r-- 1 root root  234206 Aug 16  2014 COCO_train2014_000000549042.jpg
# -rw-rw-r-- 1 root root  127798 Aug 16  2014 COCO_train2014_000000549044.jpg
# -rw-rw-r-- 1 root root  272500 Aug 16  2014 COCO_train2014_000000549088.jpg
# -rw-rw-r-- 1 root root  119476 Aug 16  2014 COCO_train2014_000000549098.jpg
# -rw-rw-r-- 1 root root  107940 Aug 16  2014 COCO_train2014_000000549101.jpg
# -rw-rw-r-- 1 root root  204530 Aug 16  2014 COCO_train2014_000000549104.jpg
# -rw-rw-r-- 1 root root  150611 Aug 16  2014 COCO_train2014_000000549114.jpg
# -rw-rw-r-- 1 root root  171388 Aug 16  2014 COCO_train2014_000000549115.jpg
# -rw-rw-r-- 1 root root  236571 Aug 16  2014 COCO_train2014_000000549117.jpg
# -rw-rw-r-- 1 root root   69441 Aug 16  2014 COCO_train2014_000000549122.jpg
# -rw-rw-r-- 1 root root  154124 Aug 16  2014 COCO_train2014_000000549127.jpg
# -rw-rw-r-- 1 root root  214330 Aug 16  2014 COCO_train2014_000000549133.jpg
# -rw-rw-r-- 1 root root  107545 Aug 16  2014 COCO_train2014_000000549135.jpg
# -rw-rw-r-- 1 root root    8019 Aug 16  2014 COCO_train2014_000000549143.jpg
# -rw-rw-r-- 1 root root  192418 Aug 16  2014 COCO_train2014_000000549166.jpg
# -rw-rw-r-- 1 root root  123940 Aug 16  2014 COCO_train2014_000000549168.jpg
# -rw-rw-r-- 1 root root  112309 Aug 16  2014 COCO_train2014_000000549172.jpg
# -rw-rw-r-- 1 root root  169115 Aug 16  2014 COCO_train2014_000000549183.jpg
# -rw-rw-r-- 1 root root  135316 Aug 16  2014 COCO_train2014_000000549184.jpg
# -rw-rw-r-- 1 root root  131161 Aug 16  2014 COCO_train2014_000000549188.jpg
# -rw-rw-r-- 1 root root  201319 Aug 16  2014 COCO_train2014_000000549194.jpg
# -rw-rw-r-- 1 root root  139496 Aug 16  2014 COCO_train2014_000000549199.jpg
# -rw-rw-r-- 1 root root   69241 Aug 16  2014 COCO_train2014_000000549201.jpg
# -rw-rw-r-- 1 root root  122819 Aug 16  2014 COCO_train2014_000000549209.jpg
# -rw-rw-r-- 1 root root  164542 Aug 16  2014 COCO_train2014_000000549216.jpg
# -rw-rw-r-- 1 root root   25531 Aug 16  2014 COCO_train2014_000000549231.jpg
# -rw-rw-r-- 1 root root  117293 Aug 16  2014 COCO_train2014_000000549236.jpg
# -rw-rw-r-- 1 root root  267788 Aug 16  2014 COCO_train2014_000000549237.jpg
# -rw-rw-r-- 1 root root  127534 Aug 16  2014 COCO_train2014_000000549239.jpg
# -rw-rw-r-- 1 root root  162419 Aug 16  2014 COCO_train2014_000000549256.jpg
# -rw-rw-r-- 1 root root  163039 Aug 16  2014 COCO_train2014_000000549276.jpg
# -rw-rw-r-- 1 root root  226488 Aug 16  2014 COCO_train2014_000000549284.jpg
# -rw-rw-r-- 1 root root  291623 Aug 16  2014 COCO_train2014_000000549287.jpg
# -rw-rw-r-- 1 root root  181788 Aug 16  2014 COCO_train2014_000000549301.jpg
# -rw-rw-r-- 1 root root  139940 Aug 16  2014 COCO_train2014_000000549317.jpg
# -rw-rw-r-- 1 root root  156996 Aug 16  2014 COCO_train2014_000000549328.jpg
# -rw-rw-r-- 1 root root  193458 Aug 16  2014 COCO_train2014_000000549330.jpg
# -rw-rw-r-- 1 root root  234349 Aug 16  2014 COCO_train2014_000000549347.jpg
# -rw-rw-r-- 1 root root  238585 Aug 16  2014 COCO_train2014_000000549366.jpg
# -rw-rw-r-- 1 root root  163857 Aug 16  2014 COCO_train2014_000000549373.jpg
# -rw-rw-r-- 1 root root  225237 Aug 16  2014 COCO_train2014_000000549375.jpg
# -rw-rw-r-- 1 root root  195536 Aug 16  2014 COCO_train2014_000000549377.jpg
# -rw-rw-r-- 1 root root   18632 Aug 16  2014 COCO_train2014_000000549378.jpg
# -rw-rw-r-- 1 root root  334029 Aug 16  2014 COCO_train2014_000000549394.jpg
# -rw-rw-r-- 1 root root  211619 Aug 16  2014 COCO_train2014_000000549400.jpg
# -rw-rw-r-- 1 root root   73831 Aug 16  2014 COCO_train2014_000000549404.jpg
# -rw-rw-r-- 1 root root   48982 Aug 16  2014 COCO_train2014_000000549407.jpg
# -rw-rw-r-- 1 root root  169881 Aug 16  2014 COCO_train2014_000000549409.jpg
# -rw-rw-r-- 1 root root  107139 Aug 16  2014 COCO_train2014_000000549413.jpg
# -rw-rw-r-- 1 root root  249663 Aug 16  2014 COCO_train2014_000000549422.jpg
# -rw-rw-r-- 1 root root  135488 Aug 16  2014 COCO_train2014_000000549423.jpg
# -rw-rw-r-- 1 root root  154463 Aug 16  2014 COCO_train2014_000000549426.jpg
# -rw-rw-r-- 1 root root  116248 Aug 16  2014 COCO_train2014_000000549435.jpg
# -rw-rw-r-- 1 root root  263413 Aug 16  2014 COCO_train2014_000000549442.jpg
# -rw-rw-r-- 1 root root  250439 Aug 16  2014 COCO_train2014_000000549447.jpg
# -rw-rw-r-- 1 root root   83681 Aug 16  2014 COCO_train2014_000000549454.jpg
# -rw-rw-r-- 1 root root  141068 Aug 16  2014 COCO_train2014_000000549459.jpg
# -rw-rw-r-- 1 root root  201304 Aug 16  2014 COCO_train2014_000000549471.jpg
# -rw-rw-r-- 1 root root  204869 Aug 16  2014 COCO_train2014_000000549478.jpg
# -rw-rw-r-- 1 root root   81777 Aug 16  2014 COCO_train2014_000000549488.jpg
# -rw-rw-r-- 1 root root   74457 Aug 16  2014 COCO_train2014_000000549490.jpg
# -rw-rw-r-- 1 root root  246204 Aug 16  2014 COCO_train2014_000000549496.jpg
# -rw-rw-r-- 1 root root  144923 Aug 16  2014 COCO_train2014_000000549499.jpg
# -rw-rw-r-- 1 root root  132375 Aug 16  2014 COCO_train2014_000000549501.jpg
# -rw-rw-r-- 1 root root  105984 Aug 16  2014 COCO_train2014_000000549506.jpg
# -rw-rw-r-- 1 root root  160360 Aug 16  2014 COCO_train2014_000000549517.jpg
# -rw-rw-r-- 1 root root   91916 Aug 16  2014 COCO_train2014_000000549519.jpg
# -rw-rw-r-- 1 root root  196434 Aug 16  2014 COCO_train2014_000000549527.jpg
# -rw-rw-r-- 1 root root  152184 Aug 16  2014 COCO_train2014_000000549532.jpg
# -rw-rw-r-- 1 root root  128956 Aug 16  2014 COCO_train2014_000000549534.jpg
# -rw-rw-r-- 1 root root  166309 Aug 16  2014 COCO_train2014_000000549535.jpg
# -rw-rw-r-- 1 root root   84388 Aug 16  2014 COCO_train2014_000000549536.jpg
# -rw-rw-r-- 1 root root  166413 Aug 16  2014 COCO_train2014_000000549539.jpg
# -rw-rw-r-- 1 root root  146041 Aug 16  2014 COCO_train2014_000000549556.jpg
# -rw-rw-r-- 1 root root  162823 Aug 16  2014 COCO_train2014_000000549559.jpg
# -rw-rw-r-- 1 root root  120340 Aug 16  2014 COCO_train2014_000000549563.jpg
# -rw-rw-r-- 1 root root  121853 Aug 16  2014 COCO_train2014_000000549575.jpg
# -rw-rw-r-- 1 root root  159775 Aug 16  2014 COCO_train2014_000000549580.jpg
# -rw-rw-r-- 1 root root  187927 Aug 16  2014 COCO_train2014_000000549581.jpg
# -rw-rw-r-- 1 root root  132290 Aug 16  2014 COCO_train2014_000000549597.jpg
# -rw-rw-r-- 1 root root  271691 Aug 16  2014 COCO_train2014_000000549599.jpg
# -rw-rw-r-- 1 root root   44817 Aug 16  2014 COCO_train2014_000000549605.jpg
# -rw-rw-r-- 1 root root  246934 Aug 16  2014 COCO_train2014_000000549612.jpg
# -rw-rw-r-- 1 root root  200243 Aug 16  2014 COCO_train2014_000000549617.jpg
# -rw-rw-r-- 1 root root  257011 Aug 16  2014 COCO_train2014_000000549622.jpg
# -rw-rw-r-- 1 root root  206544 Aug 16  2014 COCO_train2014_000000549626.jpg
# -rw-rw-r-- 1 root root  289659 Aug 16  2014 COCO_train2014_000000549639.jpg
# -rw-rw-r-- 1 root root  147101 Aug 16  2014 COCO_train2014_000000549644.jpg
# -rw-rw-r-- 1 root root  164432 Aug 16  2014 COCO_train2014_000000549650.jpg
# -rw-rw-r-- 1 root root  222647 Aug 16  2014 COCO_train2014_000000549685.jpg
# -rw-rw-r-- 1 root root  107840 Aug 16  2014 COCO_train2014_000000549691.jpg
# -rw-rw-r-- 1 root root  141683 Aug 16  2014 COCO_train2014_000000549703.jpg
# -rw-rw-r-- 1 root root  120962 Aug 16  2014 COCO_train2014_000000549708.jpg
# -rw-rw-r-- 1 root root  180255 Aug 16  2014 COCO_train2014_000000549709.jpg
# -rw-rw-r-- 1 root root  146746 Aug 16  2014 COCO_train2014_000000549711.jpg
# -rw-rw-r-- 1 root root  131961 Aug 16  2014 COCO_train2014_000000549714.jpg
# -rw-rw-r-- 1 root root  184479 Aug 16  2014 COCO_train2014_000000549715.jpg
# -rw-rw-r-- 1 root root   59660 Aug 16  2014 COCO_train2014_000000549720.jpg
# -rw-rw-r-- 1 root root  159823 Aug 16  2014 COCO_train2014_000000549721.jpg
# -rw-rw-r-- 1 root root  102047 Aug 16  2014 COCO_train2014_000000549725.jpg
# -rw-rw-r-- 1 root root  146990 Aug 16  2014 COCO_train2014_000000549729.jpg
# -rw-rw-r-- 1 root root  165105 Aug 16  2014 COCO_train2014_000000549744.jpg
# -rw-rw-r-- 1 root root  179032 Aug 16  2014 COCO_train2014_000000549759.jpg
# -rw-rw-r-- 1 root root   94552 Aug 16  2014 COCO_train2014_000000549773.jpg
# -rw-rw-r-- 1 root root  127119 Aug 16  2014 COCO_train2014_000000549784.jpg
# -rw-rw-r-- 1 root root  140836 Aug 16  2014 COCO_train2014_000000549804.jpg
# -rw-rw-r-- 1 root root  225897 Aug 16  2014 COCO_train2014_000000549810.jpg
# -rw-rw-r-- 1 root root   81619 Aug 16  2014 COCO_train2014_000000549821.jpg
# -rw-rw-r-- 1 root root  126431 Aug 16  2014 COCO_train2014_000000549830.jpg
# -rw-rw-r-- 1 root root  282618 Aug 16  2014 COCO_train2014_000000549836.jpg
# -rw-rw-r-- 1 root root  180600 Aug 16  2014 COCO_train2014_000000549841.jpg
# -rw-rw-r-- 1 root root  230756 Aug 16  2014 COCO_train2014_000000549849.jpg
# -rw-rw-r-- 1 root root  106204 Aug 16  2014 COCO_train2014_000000549854.jpg
# -rw-rw-r-- 1 root root  232059 Aug 16  2014 COCO_train2014_000000549866.jpg
# -rw-rw-r-- 1 root root  152211 Aug 16  2014 COCO_train2014_000000549873.jpg
# -rw-rw-r-- 1 root root  126177 Aug 16  2014 COCO_train2014_000000549876.jpg
# -rw-rw-r-- 1 root root   75337 Aug 16  2014 COCO_train2014_000000549879.jpg
# -rw-rw-r-- 1 root root  108221 Aug 16  2014 COCO_train2014_000000549886.jpg
# -rw-rw-r-- 1 root root  150880 Aug 16  2014 COCO_train2014_000000549897.jpg
# -rw-rw-r-- 1 root root  128756 Aug 16  2014 COCO_train2014_000000549898.jpg
# -rw-rw-r-- 1 root root  260650 Aug 16  2014 COCO_train2014_000000549910.jpg
# -rw-rw-r-- 1 root root  240157 Aug 16  2014 COCO_train2014_000000549915.jpg
# -rw-rw-r-- 1 root root  124402 Aug 16  2014 COCO_train2014_000000549924.jpg
# -rw-rw-r-- 1 root root  211258 Aug 16  2014 COCO_train2014_000000549928.jpg
# -rw-rw-r-- 1 root root  220696 Aug 16  2014 COCO_train2014_000000549933.jpg
# -rw-rw-r-- 1 root root  185777 Aug 16  2014 COCO_train2014_000000549939.jpg
# -rw-rw-r-- 1 root root  110819 Aug 16  2014 COCO_train2014_000000549942.jpg
# -rw-rw-r-- 1 root root  121828 Aug 16  2014 COCO_train2014_000000549958.jpg
# -rw-rw-r-- 1 root root  163181 Aug 16  2014 COCO_train2014_000000549962.jpg
# -rw-rw-r-- 1 root root  147638 Aug 16  2014 COCO_train2014_000000549972.jpg
# -rw-rw-r-- 1 root root  164655 Aug 16  2014 COCO_train2014_000000549978.jpg
# -rw-rw-r-- 1 root root  170203 Aug 16  2014 COCO_train2014_000000549988.jpg
# -rw-rw-r-- 1 root root  123418 Aug 16  2014 COCO_train2014_000000549996.jpg
# -rw-rw-r-- 1 root root  166008 Aug 16  2014 COCO_train2014_000000550000.jpg
# -rw-rw-r-- 1 root root  246629 Aug 16  2014 COCO_train2014_000000550009.jpg
# -rw-rw-r-- 1 root root  202895 Aug 16  2014 COCO_train2014_000000550019.jpg
# -rw-rw-r-- 1 root root   68563 Aug 16  2014 COCO_train2014_000000550021.jpg
# -rw-rw-r-- 1 root root   55062 Aug 16  2014 COCO_train2014_000000550023.jpg
# -rw-rw-r-- 1 root root  382442 Aug 16  2014 COCO_train2014_000000550028.jpg
# -rw-rw-r-- 1 root root  130760 Aug 16  2014 COCO_train2014_000000550030.jpg
# -rw-rw-r-- 1 root root  304849 Aug 16  2014 COCO_train2014_000000550049.jpg
# -rw-rw-r-- 1 root root  139557 Aug 16  2014 COCO_train2014_000000550056.jpg
# -rw-rw-r-- 1 root root  134463 Aug 16  2014 COCO_train2014_000000550063.jpg
# -rw-rw-r-- 1 root root  106696 Aug 16  2014 COCO_train2014_000000550066.jpg
# -rw-rw-r-- 1 root root  145044 Aug 16  2014 COCO_train2014_000000550089.jpg
# -rw-rw-r-- 1 root root   97756 Aug 16  2014 COCO_train2014_000000550093.jpg
# -rw-rw-r-- 1 root root  137920 Aug 16  2014 COCO_train2014_000000550094.jpg
# -rw-rw-r-- 1 root root  175818 Aug 16  2014 COCO_train2014_000000550097.jpg
# -rw-rw-r-- 1 root root  241815 Aug 16  2014 COCO_train2014_000000550099.jpg
# -rw-rw-r-- 1 root root   97756 Aug 16  2014 COCO_train2014_000000550104.jpg
# -rw-rw-r-- 1 root root  135937 Aug 16  2014 COCO_train2014_000000550112.jpg
# -rw-rw-r-- 1 root root  196498 Aug 16  2014 COCO_train2014_000000550113.jpg
# -rw-rw-r-- 1 root root  197075 Aug 16  2014 COCO_train2014_000000550118.jpg
# -rw-rw-r-- 1 root root  136316 Aug 16  2014 COCO_train2014_000000550126.jpg
# -rw-rw-r-- 1 root root   96058 Aug 16  2014 COCO_train2014_000000550127.jpg
# -rw-rw-r-- 1 root root   55433 Aug 16  2014 COCO_train2014_000000550129.jpg
# -rw-rw-r-- 1 root root  194953 Aug 16  2014 COCO_train2014_000000550133.jpg
# -rw-rw-r-- 1 root root  325708 Aug 16  2014 COCO_train2014_000000550134.jpg
# -rw-rw-r-- 1 root root   89928 Aug 16  2014 COCO_train2014_000000550140.jpg
# -rw-rw-r-- 1 root root   63865 Aug 16  2014 COCO_train2014_000000550144.jpg
# -rw-rw-r-- 1 root root  198480 Aug 16  2014 COCO_train2014_000000550147.jpg
# -rw-rw-r-- 1 root root  200991 Aug 16  2014 COCO_train2014_000000550157.jpg
# -rw-rw-r-- 1 root root   77281 Aug 16  2014 COCO_train2014_000000550181.jpg
# -rw-rw-r-- 1 root root  208939 Aug 16  2014 COCO_train2014_000000550193.jpg
# -rw-rw-r-- 1 root root  157599 Aug 16  2014 COCO_train2014_000000550206.jpg
# -rw-rw-r-- 1 root root  157708 Aug 16  2014 COCO_train2014_000000550221.jpg
# -rw-rw-r-- 1 root root  183382 Aug 16  2014 COCO_train2014_000000550222.jpg
# -rw-rw-r-- 1 root root  111768 Aug 16  2014 COCO_train2014_000000550235.jpg
# -rw-rw-r-- 1 root root  173079 Aug 16  2014 COCO_train2014_000000550237.jpg
# -rw-rw-r-- 1 root root   93154 Aug 16  2014 COCO_train2014_000000550239.jpg
# -rw-rw-r-- 1 root root  209795 Aug 16  2014 COCO_train2014_000000550246.jpg
# -rw-rw-r-- 1 root root  196264 Aug 16  2014 COCO_train2014_000000550258.jpg
# -rw-rw-r-- 1 root root  121372 Aug 16  2014 COCO_train2014_000000550265.jpg
# -rw-rw-r-- 1 root root  142004 Aug 16  2014 COCO_train2014_000000550277.jpg
# -rw-rw-r-- 1 root root  213612 Aug 16  2014 COCO_train2014_000000550278.jpg
# -rw-rw-r-- 1 root root  148677 Aug 16  2014 COCO_train2014_000000550298.jpg
# -rw-rw-r-- 1 root root  108377 Aug 16  2014 COCO_train2014_000000550303.jpg
# -rw-rw-r-- 1 root root   51427 Aug 16  2014 COCO_train2014_000000550306.jpg
# -rw-rw-r-- 1 root root  164406 Aug 16  2014 COCO_train2014_000000550308.jpg
# -rw-rw-r-- 1 root root   95139 Aug 16  2014 COCO_train2014_000000550310.jpg
# -rw-rw-r-- 1 root root  123089 Aug 16  2014 COCO_train2014_000000550311.jpg
# -rw-rw-r-- 1 root root   73430 Aug 16  2014 COCO_train2014_000000550313.jpg
# -rw-rw-r-- 1 root root    9133 Aug 16  2014 COCO_train2014_000000550315.jpg
# -rw-rw-r-- 1 root root  183563 Aug 16  2014 COCO_train2014_000000550324.jpg
# -rw-rw-r-- 1 root root  167065 Aug 16  2014 COCO_train2014_000000550333.jpg
# -rw-rw-r-- 1 root root  182451 Aug 16  2014 COCO_train2014_000000550338.jpg
# -rw-rw-r-- 1 root root  107048 Aug 16  2014 COCO_train2014_000000550341.jpg
# -rw-rw-r-- 1 root root  108152 Aug 16  2014 COCO_train2014_000000550353.jpg
# -rw-rw-r-- 1 root root  148618 Aug 16  2014 COCO_train2014_000000550354.jpg
# -rw-rw-r-- 1 root root   61226 Aug 16  2014 COCO_train2014_000000550355.jpg
# -rw-rw-r-- 1 root root  223435 Aug 16  2014 COCO_train2014_000000550356.jpg
# -rw-rw-r-- 1 root root   82289 Aug 16  2014 COCO_train2014_000000550359.jpg
# -rw-rw-r-- 1 root root  185133 Aug 16  2014 COCO_train2014_000000550369.jpg
# -rw-rw-r-- 1 root root   95940 Aug 16  2014 COCO_train2014_000000550391.jpg
# -rw-rw-r-- 1 root root  126558 Aug 16  2014 COCO_train2014_000000550392.jpg
# -rw-rw-r-- 1 root root  135248 Aug 16  2014 COCO_train2014_000000550394.jpg
# -rw-rw-r-- 1 root root  130256 Aug 16  2014 COCO_train2014_000000550395.jpg
# -rw-rw-r-- 1 root root   52192 Aug 16  2014 COCO_train2014_000000550396.jpg
# -rw-rw-r-- 1 root root  133455 Aug 16  2014 COCO_train2014_000000550410.jpg
# -rw-rw-r-- 1 root root  253509 Aug 16  2014 COCO_train2014_000000550414.jpg
# -rw-rw-r-- 1 root root  121617 Aug 16  2014 COCO_train2014_000000550421.jpg
# -rw-rw-r-- 1 root root   49228 Aug 16  2014 COCO_train2014_000000550435.jpg
# -rw-rw-r-- 1 root root  138791 Aug 16  2014 COCO_train2014_000000550438.jpg
# -rw-rw-r-- 1 root root   96340 Aug 16  2014 COCO_train2014_000000550445.jpg
# -rw-rw-r-- 1 root root  350822 Aug 16  2014 COCO_train2014_000000550448.jpg
# -rw-rw-r-- 1 root root  197055 Aug 16  2014 COCO_train2014_000000550449.jpg
# -rw-rw-r-- 1 root root  154602 Aug 16  2014 COCO_train2014_000000550453.jpg
# -rw-rw-r-- 1 root root  187457 Aug 16  2014 COCO_train2014_000000550455.jpg
# -rw-rw-r-- 1 root root  205661 Aug 16  2014 COCO_train2014_000000550466.jpg
# -rw-rw-r-- 1 root root  165158 Aug 16  2014 COCO_train2014_000000550467.jpg
# -rw-rw-r-- 1 root root  137784 Aug 16  2014 COCO_train2014_000000550476.jpg
# -rw-rw-r-- 1 root root  225317 Aug 16  2014 COCO_train2014_000000550478.jpg
# -rw-rw-r-- 1 root root  125107 Aug 16  2014 COCO_train2014_000000550481.jpg
# -rw-rw-r-- 1 root root  175018 Aug 16  2014 COCO_train2014_000000550482.jpg
# -rw-rw-r-- 1 root root  168053 Aug 16  2014 COCO_train2014_000000550512.jpg
# -rw-rw-r-- 1 root root  238139 Aug 16  2014 COCO_train2014_000000550518.jpg
# -rw-rw-r-- 1 root root  119494 Aug 16  2014 COCO_train2014_000000550532.jpg
# -rw-rw-r-- 1 root root  212808 Aug 16  2014 COCO_train2014_000000550534.jpg
# -rw-rw-r-- 1 root root  184735 Aug 16  2014 COCO_train2014_000000550536.jpg
# -rw-rw-r-- 1 root root  128492 Aug 16  2014 COCO_train2014_000000550540.jpg
# -rw-rw-r-- 1 root root  181232 Aug 16  2014 COCO_train2014_000000550543.jpg
# -rw-rw-r-- 1 root root  141982 Aug 16  2014 COCO_train2014_000000550545.jpg
# -rw-rw-r-- 1 root root  241491 Aug 16  2014 COCO_train2014_000000550547.jpg
# -rw-rw-r-- 1 root root  345613 Aug 16  2014 COCO_train2014_000000550555.jpg
# -rw-rw-r-- 1 root root  231898 Aug 16  2014 COCO_train2014_000000550569.jpg
# -rw-rw-r-- 1 root root  166880 Aug 16  2014 COCO_train2014_000000550572.jpg
# -rw-rw-r-- 1 root root  255323 Aug 16  2014 COCO_train2014_000000550610.jpg
# -rw-rw-r-- 1 root root  123248 Aug 16  2014 COCO_train2014_000000550617.jpg
# -rw-rw-r-- 1 root root  157026 Aug 16  2014 COCO_train2014_000000550624.jpg
# -rw-rw-r-- 1 root root  214017 Aug 16  2014 COCO_train2014_000000550642.jpg
# -rw-rw-r-- 1 root root  128342 Aug 16  2014 COCO_train2014_000000550649.jpg
# -rw-rw-r-- 1 root root  176137 Aug 16  2014 COCO_train2014_000000550652.jpg
# -rw-rw-r-- 1 root root  187039 Aug 16  2014 COCO_train2014_000000550655.jpg
# -rw-rw-r-- 1 root root  165724 Aug 16  2014 COCO_train2014_000000550660.jpg
# -rw-rw-r-- 1 root root  276301 Aug 16  2014 COCO_train2014_000000550670.jpg
# -rw-rw-r-- 1 root root   52084 Aug 16  2014 COCO_train2014_000000550674.jpg
# -rw-rw-r-- 1 root root   69263 Aug 16  2014 COCO_train2014_000000550690.jpg
# -rw-rw-r-- 1 root root  268435 Aug 16  2014 COCO_train2014_000000550699.jpg
# -rw-rw-r-- 1 root root   89892 Aug 16  2014 COCO_train2014_000000550703.jpg
# -rw-rw-r-- 1 root root  187863 Aug 16  2014 COCO_train2014_000000550719.jpg
# -rw-rw-r-- 1 root root  172637 Aug 16  2014 COCO_train2014_000000550726.jpg
# -rw-rw-r-- 1 root root   92723 Aug 16  2014 COCO_train2014_000000550736.jpg
# -rw-rw-r-- 1 root root  257298 Aug 16  2014 COCO_train2014_000000550739.jpg
# -rw-rw-r-- 1 root root  165913 Aug 16  2014 COCO_train2014_000000550745.jpg
# -rw-rw-r-- 1 root root  167266 Aug 16  2014 COCO_train2014_000000550746.jpg
# -rw-rw-r-- 1 root root  114466 Aug 16  2014 COCO_train2014_000000550747.jpg
# -rw-rw-r-- 1 root root  172197 Aug 16  2014 COCO_train2014_000000550759.jpg
# -rw-rw-r-- 1 root root  181076 Aug 16  2014 COCO_train2014_000000550760.jpg
# -rw-rw-r-- 1 root root   43290 Aug 16  2014 COCO_train2014_000000550761.jpg
# -rw-rw-r-- 1 root root  205714 Aug 16  2014 COCO_train2014_000000550766.jpg
# -rw-rw-r-- 1 root root  115093 Aug 16  2014 COCO_train2014_000000550767.jpg
# -rw-rw-r-- 1 root root  116304 Aug 16  2014 COCO_train2014_000000550780.jpg
# -rw-rw-r-- 1 root root  175331 Aug 16  2014 COCO_train2014_000000550783.jpg
# -rw-rw-r-- 1 root root  111793 Aug 16  2014 COCO_train2014_000000550787.jpg
# -rw-rw-r-- 1 root root  108069 Aug 16  2014 COCO_train2014_000000550796.jpg
# -rw-rw-r-- 1 root root  258976 Aug 16  2014 COCO_train2014_000000550812.jpg
# -rw-rw-r-- 1 root root  136121 Aug 16  2014 COCO_train2014_000000550824.jpg
# -rw-rw-r-- 1 root root  187506 Aug 16  2014 COCO_train2014_000000550834.jpg
# -rw-rw-r-- 1 root root  297721 Aug 16  2014 COCO_train2014_000000550839.jpg
# -rw-rw-r-- 1 root root  178173 Aug 16  2014 COCO_train2014_000000550842.jpg
# -rw-rw-r-- 1 root root  121522 Aug 16  2014 COCO_train2014_000000550844.jpg
# -rw-rw-r-- 1 root root  132945 Aug 16  2014 COCO_train2014_000000550845.jpg
# -rw-rw-r-- 1 root root  131975 Aug 16  2014 COCO_train2014_000000550853.jpg
# -rw-rw-r-- 1 root root  218356 Aug 16  2014 COCO_train2014_000000550869.jpg
# -rw-rw-r-- 1 root root  140114 Aug 16  2014 COCO_train2014_000000550870.jpg
# -rw-rw-r-- 1 root root  152593 Aug 16  2014 COCO_train2014_000000550874.jpg
# -rw-rw-r-- 1 root root  259606 Aug 16  2014 COCO_train2014_000000550875.jpg
# -rw-rw-r-- 1 root root  187078 Aug 16  2014 COCO_train2014_000000550878.jpg
# -rw-rw-r-- 1 root root  123963 Aug 16  2014 COCO_train2014_000000550906.jpg
# -rw-rw-r-- 1 root root  199978 Aug 16  2014 COCO_train2014_000000550911.jpg
# -rw-rw-r-- 1 root root  155180 Aug 16  2014 COCO_train2014_000000550912.jpg
# -rw-rw-r-- 1 root root   86278 Aug 16  2014 COCO_train2014_000000550925.jpg
# -rw-rw-r-- 1 root root  110008 Aug 16  2014 COCO_train2014_000000550934.jpg
# -rw-rw-r-- 1 root root  148666 Aug 16  2014 COCO_train2014_000000550944.jpg
# -rw-rw-r-- 1 root root  133902 Aug 16  2014 COCO_train2014_000000550955.jpg
# -rw-rw-r-- 1 root root  217608 Aug 16  2014 COCO_train2014_000000550960.jpg
# -rw-rw-r-- 1 root root  169727 Aug 16  2014 COCO_train2014_000000550972.jpg
# -rw-rw-r-- 1 root root   87039 Aug 16  2014 COCO_train2014_000000550978.jpg
# -rw-rw-r-- 1 root root  218423 Aug 16  2014 COCO_train2014_000000550979.jpg
# -rw-rw-r-- 1 root root  193903 Aug 16  2014 COCO_train2014_000000550993.jpg
# -rw-rw-r-- 1 root root  117458 Aug 16  2014 COCO_train2014_000000551014.jpg
# -rw-rw-r-- 1 root root  162588 Aug 16  2014 COCO_train2014_000000551015.jpg
# -rw-rw-r-- 1 root root   91512 Aug 16  2014 COCO_train2014_000000551023.jpg
# -rw-rw-r-- 1 root root  237393 Aug 16  2014 COCO_train2014_000000551024.jpg
# -rw-rw-r-- 1 root root   85425 Aug 16  2014 COCO_train2014_000000551031.jpg
# -rw-rw-r-- 1 root root   82211 Aug 16  2014 COCO_train2014_000000551036.jpg
# -rw-rw-r-- 1 root root   38496 Aug 16  2014 COCO_train2014_000000551042.jpg
# -rw-rw-r-- 1 root root  110651 Aug 16  2014 COCO_train2014_000000551050.jpg
# -rw-rw-r-- 1 root root  231183 Aug 16  2014 COCO_train2014_000000551062.jpg
# -rw-rw-r-- 1 root root  242833 Aug 16  2014 COCO_train2014_000000551063.jpg
# -rw-rw-r-- 1 root root  168443 Aug 16  2014 COCO_train2014_000000551073.jpg
# -rw-rw-r-- 1 root root   68138 Aug 16  2014 COCO_train2014_000000551074.jpg
# -rw-rw-r-- 1 root root  253737 Aug 16  2014 COCO_train2014_000000551082.jpg
# -rw-rw-r-- 1 root root  229073 Aug 16  2014 COCO_train2014_000000551088.jpg
# -rw-rw-r-- 1 root root  109914 Aug 16  2014 COCO_train2014_000000551099.jpg
# -rw-rw-r-- 1 root root  178719 Aug 16  2014 COCO_train2014_000000551100.jpg
# -rw-rw-r-- 1 root root  250450 Aug 16  2014 COCO_train2014_000000551118.jpg
# -rw-rw-r-- 1 root root  132105 Aug 16  2014 COCO_train2014_000000551125.jpg
# -rw-rw-r-- 1 root root   96687 Aug 16  2014 COCO_train2014_000000551144.jpg
# -rw-rw-r-- 1 root root   80536 Aug 16  2014 COCO_train2014_000000551148.jpg
# -rw-rw-r-- 1 root root  237701 Aug 16  2014 COCO_train2014_000000551159.jpg
# -rw-rw-r-- 1 root root   59320 Aug 16  2014 COCO_train2014_000000551164.jpg
# -rw-rw-r-- 1 root root  103106 Aug 16  2014 COCO_train2014_000000551166.jpg
# -rw-rw-r-- 1 root root  164774 Aug 16  2014 COCO_train2014_000000551169.jpg
# -rw-rw-r-- 1 root root   81169 Aug 16  2014 COCO_train2014_000000551172.jpg
# -rw-rw-r-- 1 root root   73320 Aug 16  2014 COCO_train2014_000000551175.jpg
# -rw-rw-r-- 1 root root  132250 Aug 16  2014 COCO_train2014_000000551185.jpg
# -rw-rw-r-- 1 root root  147399 Aug 16  2014 COCO_train2014_000000551189.jpg
# -rw-rw-r-- 1 root root  127608 Aug 16  2014 COCO_train2014_000000551194.jpg
# -rw-rw-r-- 1 root root  168960 Aug 16  2014 COCO_train2014_000000551197.jpg
# -rw-rw-r-- 1 root root  124643 Aug 16  2014 COCO_train2014_000000551206.jpg
# -rw-rw-r-- 1 root root   82983 Aug 16  2014 COCO_train2014_000000551214.jpg
# -rw-rw-r-- 1 root root  141609 Aug 16  2014 COCO_train2014_000000551227.jpg
# -rw-rw-r-- 1 root root  205216 Aug 16  2014 COCO_train2014_000000551244.jpg
# -rw-rw-r-- 1 root root  350420 Aug 16  2014 COCO_train2014_000000551246.jpg
# -rw-rw-r-- 1 root root  207020 Aug 16  2014 COCO_train2014_000000551260.jpg
# -rw-rw-r-- 1 root root  155312 Aug 16  2014 COCO_train2014_000000551267.jpg
# -rw-rw-r-- 1 root root  158373 Aug 16  2014 COCO_train2014_000000551275.jpg
# -rw-rw-r-- 1 root root   79401 Aug 16  2014 COCO_train2014_000000551279.jpg
# -rw-rw-r-- 1 root root  205838 Aug 16  2014 COCO_train2014_000000551284.jpg
# -rw-rw-r-- 1 root root  235487 Aug 16  2014 COCO_train2014_000000551285.jpg
# -rw-rw-r-- 1 root root  144334 Aug 16  2014 COCO_train2014_000000551299.jpg
# -rw-rw-r-- 1 root root  101773 Aug 16  2014 COCO_train2014_000000551303.jpg
# -rw-rw-r-- 1 root root  194901 Aug 16  2014 COCO_train2014_000000551305.jpg
# -rw-rw-r-- 1 root root  123003 Aug 16  2014 COCO_train2014_000000551314.jpg
# -rw-rw-r-- 1 root root  195561 Aug 16  2014 COCO_train2014_000000551316.jpg
# -rw-rw-r-- 1 root root  130538 Aug 16  2014 COCO_train2014_000000551327.jpg
# -rw-rw-r-- 1 root root  154072 Aug 16  2014 COCO_train2014_000000551341.jpg
# -rw-rw-r-- 1 root root  154463 Aug 16  2014 COCO_train2014_000000551344.jpg
# -rw-rw-r-- 1 root root  144834 Aug 16  2014 COCO_train2014_000000551349.jpg
# -rw-rw-r-- 1 root root  331104 Aug 16  2014 COCO_train2014_000000551357.jpg
# -rw-rw-r-- 1 root root  117206 Aug 16  2014 COCO_train2014_000000551359.jpg
# -rw-rw-r-- 1 root root  182954 Aug 16  2014 COCO_train2014_000000551364.jpg
# -rw-rw-r-- 1 root root  212785 Aug 16  2014 COCO_train2014_000000551372.jpg
# -rw-rw-r-- 1 root root   74717 Aug 16  2014 COCO_train2014_000000551389.jpg
# -rw-rw-r-- 1 root root  259646 Aug 16  2014 COCO_train2014_000000551413.jpg
# -rw-rw-r-- 1 root root  237560 Aug 16  2014 COCO_train2014_000000551418.jpg
# -rw-rw-r-- 1 root root  165045 Aug 16  2014 COCO_train2014_000000551427.jpg
# -rw-rw-r-- 1 root root  148495 Aug 16  2014 COCO_train2014_000000551433.jpg
# -rw-rw-r-- 1 root root  190574 Aug 16  2014 COCO_train2014_000000551434.jpg
# -rw-rw-r-- 1 root root  276182 Aug 16  2014 COCO_train2014_000000551438.jpg
# -rw-rw-r-- 1 root root  143415 Aug 16  2014 COCO_train2014_000000551441.jpg
# -rw-rw-r-- 1 root root  290660 Aug 16  2014 COCO_train2014_000000551446.jpg
# -rw-rw-r-- 1 root root  104997 Aug 16  2014 COCO_train2014_000000551464.jpg
# -rw-rw-r-- 1 root root  112573 Aug 16  2014 COCO_train2014_000000551466.jpg
# -rw-rw-r-- 1 root root  143861 Aug 16  2014 COCO_train2014_000000551470.jpg
# -rw-rw-r-- 1 root root  122841 Aug 16  2014 COCO_train2014_000000551472.jpg
# -rw-rw-r-- 1 root root  228710 Aug 16  2014 COCO_train2014_000000551481.jpg
# -rw-rw-r-- 1 root root  163727 Aug 16  2014 COCO_train2014_000000551486.jpg
# -rw-rw-r-- 1 root root  297718 Aug 16  2014 COCO_train2014_000000551507.jpg
# -rw-rw-r-- 1 root root   80491 Aug 16  2014 COCO_train2014_000000551515.jpg
# -rw-rw-r-- 1 root root  192466 Aug 16  2014 COCO_train2014_000000551522.jpg
# -rw-rw-r-- 1 root root  228652 Aug 16  2014 COCO_train2014_000000551524.jpg
# -rw-rw-r-- 1 root root  109917 Aug 16  2014 COCO_train2014_000000551542.jpg
# -rw-rw-r-- 1 root root   57962 Aug 16  2014 COCO_train2014_000000551553.jpg
# -rw-rw-r-- 1 root root  105312 Aug 16  2014 COCO_train2014_000000551571.jpg
# -rw-rw-r-- 1 root root   50349 Aug 16  2014 COCO_train2014_000000551574.jpg
# -rw-rw-r-- 1 root root  157543 Aug 16  2014 COCO_train2014_000000551575.jpg
# -rw-rw-r-- 1 root root  113954 Aug 16  2014 COCO_train2014_000000551590.jpg
# -rw-rw-r-- 1 root root  189969 Aug 16  2014 COCO_train2014_000000551594.jpg
# -rw-rw-r-- 1 root root  226254 Aug 16  2014 COCO_train2014_000000551595.jpg
# -rw-rw-r-- 1 root root  136318 Aug 16  2014 COCO_train2014_000000551597.jpg
# -rw-rw-r-- 1 root root  170532 Aug 16  2014 COCO_train2014_000000551598.jpg
# -rw-rw-r-- 1 root root  185785 Aug 16  2014 COCO_train2014_000000551607.jpg
# -rw-rw-r-- 1 root root  255150 Aug 16  2014 COCO_train2014_000000551609.jpg
# -rw-rw-r-- 1 root root  156979 Aug 16  2014 COCO_train2014_000000551630.jpg
# -rw-rw-r-- 1 root root  113495 Aug 16  2014 COCO_train2014_000000551631.jpg
# -rw-rw-r-- 1 root root  204072 Aug 16  2014 COCO_train2014_000000551636.jpg
# -rw-rw-r-- 1 root root  245409 Aug 16  2014 COCO_train2014_000000551647.jpg
# -rw-rw-r-- 1 root root  208464 Aug 16  2014 COCO_train2014_000000551651.jpg
# -rw-rw-r-- 1 root root  182256 Aug 16  2014 COCO_train2014_000000551657.jpg
# -rw-rw-r-- 1 root root  134809 Aug 16  2014 COCO_train2014_000000551661.jpg
# -rw-rw-r-- 1 root root  207977 Aug 16  2014 COCO_train2014_000000551663.jpg
# -rw-rw-r-- 1 root root  141358 Aug 16  2014 COCO_train2014_000000551676.jpg
# -rw-rw-r-- 1 root root  259009 Aug 16  2014 COCO_train2014_000000551677.jpg
# -rw-rw-r-- 1 root root  243033 Aug 16  2014 COCO_train2014_000000551679.jpg
# -rw-rw-r-- 1 root root  151282 Aug 16  2014 COCO_train2014_000000551686.jpg
# -rw-rw-r-- 1 root root  189917 Aug 16  2014 COCO_train2014_000000551701.jpg
# -rw-rw-r-- 1 root root  281163 Aug 16  2014 COCO_train2014_000000551710.jpg
# -rw-rw-r-- 1 root root  320584 Aug 16  2014 COCO_train2014_000000551717.jpg
# -rw-rw-r-- 1 root root   88341 Aug 16  2014 COCO_train2014_000000551718.jpg
# -rw-rw-r-- 1 root root  167222 Aug 16  2014 COCO_train2014_000000551733.jpg
# -rw-rw-r-- 1 root root   95684 Aug 16  2014 COCO_train2014_000000551735.jpg
# -rw-rw-r-- 1 root root  134355 Aug 16  2014 COCO_train2014_000000551736.jpg
# -rw-rw-r-- 1 root root   97754 Aug 16  2014 COCO_train2014_000000551746.jpg
# -rw-rw-r-- 1 root root  143935 Aug 16  2014 COCO_train2014_000000551752.jpg
# -rw-rw-r-- 1 root root   88478 Aug 16  2014 COCO_train2014_000000551757.jpg
# -rw-rw-r-- 1 root root  181357 Aug 16  2014 COCO_train2014_000000551763.jpg
# -rw-rw-r-- 1 root root  192843 Aug 16  2014 COCO_train2014_000000551793.jpg
# -rw-rw-r-- 1 root root  241150 Aug 16  2014 COCO_train2014_000000551795.jpg
# -rw-rw-r-- 1 root root  198097 Aug 16  2014 COCO_train2014_000000551802.jpg
# -rw-rw-r-- 1 root root  232701 Aug 16  2014 COCO_train2014_000000551814.jpg
# -rw-rw-r-- 1 root root  184849 Aug 16  2014 COCO_train2014_000000551823.jpg
# -rw-rw-r-- 1 root root  225176 Aug 16  2014 COCO_train2014_000000551829.jpg
# -rw-rw-r-- 1 root root   52233 Aug 16  2014 COCO_train2014_000000551832.jpg
# -rw-rw-r-- 1 root root  239243 Aug 16  2014 COCO_train2014_000000551836.jpg
# -rw-rw-r-- 1 root root  220158 Aug 16  2014 COCO_train2014_000000551840.jpg
# ...
# -rw-rw-r-- 1 root root   78117 Aug 16  2014 COCO_train2014_000000580431.jpg
# -rw-rw-r-- 1 root root  197456 Aug 16  2014 COCO_train2014_000000580434.jpg
# -rw-rw-r-- 1 root root  138864 Aug 16  2014 COCO_train2014_000000580446.jpg
# -rw-rw-r-- 1 root root  116852 Aug 16  2014 COCO_train2014_000000580454.jpg
# -rw-rw-r-- 1 root root   93125 Aug 16  2014 COCO_train2014_000000580459.jpg
# -rw-rw-r-- 1 root root  133266 Aug 16  2014 COCO_train2014_000000580461.jpg
# -rw-rw-r-- 1 root root  420903 Aug 16  2014 COCO_train2014_000000580466.jpg
# -rw-rw-r-- 1 root root   84503 Aug 16  2014 COCO_train2014_000000580487.jpg
# -rw-rw-r-- 1 root root  198430 Aug 16  2014 COCO_train2014_000000580505.jpg
# -rw-rw-r-- 1 root root  261415 Aug 16  2014 COCO_train2014_000000580507.jpg
# -rw-rw-r-- 1 root root  196590 Aug 16  2014 COCO_train2014_000000580510.jpg
# -rw-rw-r-- 1 root root  103519 Aug 16  2014 COCO_train2014_000000580511.jpg
# -rw-rw-r-- 1 root root  164682 Aug 16  2014 COCO_train2014_000000580512.jpg
# -rw-rw-r-- 1 root root  148578 Aug 16  2014 COCO_train2014_000000580523.jpg
# -rw-rw-r-- 1 root root  185782 Aug 16  2014 COCO_train2014_000000580525.jpg
# -rw-rw-r-- 1 root root  172777 Aug 16  2014 COCO_train2014_000000580538.jpg
# -rw-rw-r-- 1 root root  115730 Aug 16  2014 COCO_train2014_000000580539.jpg
# -rw-rw-r-- 1 root root  180385 Aug 16  2014 COCO_train2014_000000580541.jpg
# -rw-rw-r-- 1 root root  233259 Aug 16  2014 COCO_train2014_000000580549.jpg
# -rw-rw-r-- 1 root root  203676 Aug 16  2014 COCO_train2014_000000580562.jpg
# -rw-rw-r-- 1 root root  104875 Aug 16  2014 COCO_train2014_000000580579.jpg
# -rw-rw-r-- 1 root root   36538 Aug 16  2014 COCO_train2014_000000580585.jpg
# -rw-rw-r-- 1 root root  124967 Aug 16  2014 COCO_train2014_000000580586.jpg
# -rw-rw-r-- 1 root root  205828 Aug 16  2014 COCO_train2014_000000580600.jpg
# -rw-rw-r-- 1 root root  126172 Aug 16  2014 COCO_train2014_000000580609.jpg
# -rw-rw-r-- 1 root root   91248 Aug 16  2014 COCO_train2014_000000580620.jpg
# -rw-rw-r-- 1 root root   78091 Aug 16  2014 COCO_train2014_000000580625.jpg
# -rw-rw-r-- 1 root root   81754 Aug 16  2014 COCO_train2014_000000580629.jpg
# -rw-rw-r-- 1 root root  359322 Aug 16  2014 COCO_train2014_000000580631.jpg
# -rw-rw-r-- 1 root root  129903 Aug 16  2014 COCO_train2014_000000580636.jpg
# -rw-rw-r-- 1 root root   97157 Aug 16  2014 COCO_train2014_000000580649.jpg
# -rw-rw-r-- 1 root root   89228 Aug 16  2014 COCO_train2014_000000580651.jpg
# -rw-rw-r-- 1 root root  221191 Aug 16  2014 COCO_train2014_000000580652.jpg
# -rw-rw-r-- 1 root root  135655 Aug 16  2014 COCO_train2014_000000580660.jpg
# -rw-rw-r-- 1 root root  204715 Aug 16  2014 COCO_train2014_000000580668.jpg
# -rw-rw-r-- 1 root root  158126 Aug 16  2014 COCO_train2014_000000580671.jpg
# -rw-rw-r-- 1 root root  100487 Aug 16  2014 COCO_train2014_000000580678.jpg
# -rw-rw-r-- 1 root root  171415 Aug 16  2014 COCO_train2014_000000580681.jpg
# -rw-rw-r-- 1 root root  163819 Aug 16  2014 COCO_train2014_000000580685.jpg
# -rw-rw-r-- 1 root root  281628 Aug 16  2014 COCO_train2014_000000580695.jpg
# -rw-rw-r-- 1 root root  214936 Aug 16  2014 COCO_train2014_000000580706.jpg
# -rw-rw-r-- 1 root root  240976 Aug 16  2014 COCO_train2014_000000580718.jpg
# -rw-rw-r-- 1 root root  116707 Aug 16  2014 COCO_train2014_000000580729.jpg
# -rw-rw-r-- 1 root root  234375 Aug 16  2014 COCO_train2014_000000580732.jpg
# -rw-rw-r-- 1 root root  212470 Aug 16  2014 COCO_train2014_000000580735.jpg
# -rw-rw-r-- 1 root root  124963 Aug 16  2014 COCO_train2014_000000580741.jpg
# -rw-rw-r-- 1 root root  176517 Aug 16  2014 COCO_train2014_000000580753.jpg
# -rw-rw-r-- 1 root root   68552 Aug 16  2014 COCO_train2014_000000580765.jpg
# -rw-rw-r-- 1 root root  161824 Aug 16  2014 COCO_train2014_000000580777.jpg
# -rw-rw-r-- 1 root root  110842 Aug 16  2014 COCO_train2014_000000580781.jpg
# -rw-rw-r-- 1 root root  139180 Aug 16  2014 COCO_train2014_000000580785.jpg
# -rw-rw-r-- 1 root root  248965 Aug 16  2014 COCO_train2014_000000580790.jpg
# -rw-rw-r-- 1 root root  126374 Aug 16  2014 COCO_train2014_000000580797.jpg
# -rw-rw-r-- 1 root root  155551 Aug 16  2014 COCO_train2014_000000580813.jpg
# -rw-rw-r-- 1 root root  152198 Aug 16  2014 COCO_train2014_000000580822.jpg
# -rw-rw-r-- 1 root root   86386 Aug 16  2014 COCO_train2014_000000580825.jpg
# -rw-rw-r-- 1 root root  207696 Aug 16  2014 COCO_train2014_000000580827.jpg
# -rw-rw-r-- 1 root root  160260 Aug 16  2014 COCO_train2014_000000580837.jpg
# -rw-rw-r-- 1 root root   28648 Aug 16  2014 COCO_train2014_000000580842.jpg
# -rw-rw-r-- 1 root root  229625 Aug 16  2014 COCO_train2014_000000580843.jpg
# -rw-rw-r-- 1 root root  179926 Aug 16  2014 COCO_train2014_000000580849.jpg
# -rw-rw-r-- 1 root root  208605 Aug 16  2014 COCO_train2014_000000580850.jpg
# -rw-rw-r-- 1 root root  104454 Aug 16  2014 COCO_train2014_000000580851.jpg
# -rw-rw-r-- 1 root root  124503 Aug 16  2014 COCO_train2014_000000580862.jpg
# -rw-rw-r-- 1 root root  153909 Aug 16  2014 COCO_train2014_000000580887.jpg
# -rw-rw-r-- 1 root root  225223 Aug 16  2014 COCO_train2014_000000580905.jpg
# -rw-rw-r-- 1 root root  304468 Aug 16  2014 COCO_train2014_000000580906.jpg
# -rw-rw-r-- 1 root root   87017 Aug 16  2014 COCO_train2014_000000580913.jpg
# -rw-rw-r-- 1 root root  144547 Aug 16  2014 COCO_train2014_000000580916.jpg
# -rw-rw-r-- 1 root root  205858 Aug 16  2014 COCO_train2014_000000580919.jpg
# -rw-rw-r-- 1 root root  139416 Aug 16  2014 COCO_train2014_000000580923.jpg
# -rw-rw-r-- 1 root root   48507 Aug 16  2014 COCO_train2014_000000580930.jpg
# -rw-rw-r-- 1 root root  132543 Aug 16  2014 COCO_train2014_000000580932.jpg
# -rw-rw-r-- 1 root root  185550 Aug 16  2014 COCO_train2014_000000580933.jpg
# -rw-rw-r-- 1 root root  102455 Aug 16  2014 COCO_train2014_000000580942.jpg
# -rw-rw-r-- 1 root root  115613 Aug 16  2014 COCO_train2014_000000580943.jpg
# -rw-rw-r-- 1 root root  173203 Aug 16  2014 COCO_train2014_000000580945.jpg
# -rw-rw-r-- 1 root root  173916 Aug 16  2014 COCO_train2014_000000580957.jpg
# -rw-rw-r-- 1 root root  107658 Aug 16  2014 COCO_train2014_000000580960.jpg
# -rw-rw-r-- 1 root root  116147 Aug 16  2014 COCO_train2014_000000580971.jpg
# -rw-rw-r-- 1 root root  116508 Aug 16  2014 COCO_train2014_000000580974.jpg
# -rw-rw-r-- 1 root root  140958 Aug 16  2014 COCO_train2014_000000580978.jpg
# -rw-rw-r-- 1 root root  240065 Aug 16  2014 COCO_train2014_000000580979.jpg
# -rw-rw-r-- 1 root root  153550 Aug 16  2014 COCO_train2014_000000581008.jpg
# -rw-rw-r-- 1 root root  155339 Aug 16  2014 COCO_train2014_000000581009.jpg
# -rw-rw-r-- 1 root root  118453 Aug 16  2014 COCO_train2014_000000581018.jpg
# -rw-rw-r-- 1 root root  331525 Aug 16  2014 COCO_train2014_000000581021.jpg
# -rw-rw-r-- 1 root root  195555 Aug 16  2014 COCO_train2014_000000581031.jpg
# -rw-rw-r-- 1 root root   98625 Aug 16  2014 COCO_train2014_000000581036.jpg
# -rw-rw-r-- 1 root root  157881 Aug 16  2014 COCO_train2014_000000581038.jpg
# -rw-rw-r-- 1 root root  172286 Aug 16  2014 COCO_train2014_000000581042.jpg
# -rw-rw-r-- 1 root root   72204 Aug 16  2014 COCO_train2014_000000581055.jpg
# -rw-rw-r-- 1 root root  152007 Aug 16  2014 COCO_train2014_000000581056.jpg
# -rw-rw-r-- 1 root root  213996 Aug 16  2014 COCO_train2014_000000581057.jpg
# -rw-rw-r-- 1 root root  123423 Aug 16  2014 COCO_train2014_000000581061.jpg
# -rw-rw-r-- 1 root root   41813 Aug 16  2014 COCO_train2014_000000581065.jpg
# -rw-rw-r-- 1 root root  195358 Aug 16  2014 COCO_train2014_000000581071.jpg
# -rw-rw-r-- 1 root root  210784 Aug 16  2014 COCO_train2014_000000581073.jpg
# -rw-rw-r-- 1 root root   98166 Aug 16  2014 COCO_train2014_000000581089.jpg
# -rw-rw-r-- 1 root root  125190 Aug 16  2014 COCO_train2014_000000581091.jpg
# -rw-rw-r-- 1 root root  138828 Aug 16  2014 COCO_train2014_000000581096.jpg
# -rw-rw-r-- 1 root root  143659 Aug 16  2014 COCO_train2014_000000581097.jpg
# -rw-rw-r-- 1 root root  315602 Aug 16  2014 COCO_train2014_000000581108.jpg
# -rw-rw-r-- 1 root root   43149 Aug 16  2014 COCO_train2014_000000581118.jpg
# -rw-rw-r-- 1 root root  131055 Aug 16  2014 COCO_train2014_000000581124.jpg
# -rw-rw-r-- 1 root root   62918 Aug 16  2014 COCO_train2014_000000581127.jpg
# -rw-rw-r-- 1 root root  222643 Aug 16  2014 COCO_train2014_000000581136.jpg
# -rw-rw-r-- 1 root root  274680 Aug 16  2014 COCO_train2014_000000581153.jpg
# -rw-rw-r-- 1 root root  131950 Aug 16  2014 COCO_train2014_000000581181.jpg
# -rw-rw-r-- 1 root root  161017 Aug 16  2014 COCO_train2014_000000581189.jpg
# -rw-rw-r-- 1 root root  225109 Aug 16  2014 COCO_train2014_000000581196.jpg
# -rw-rw-r-- 1 root root  176973 Aug 16  2014 COCO_train2014_000000581198.jpg
# -rw-rw-r-- 1 root root  161623 Aug 16  2014 COCO_train2014_000000581199.jpg
# -rw-rw-r-- 1 root root  259359 Aug 16  2014 COCO_train2014_000000581204.jpg
# -rw-rw-r-- 1 root root  120376 Aug 16  2014 COCO_train2014_000000581218.jpg
# -rw-rw-r-- 1 root root  145065 Aug 16  2014 COCO_train2014_000000581220.jpg
# -rw-rw-r-- 1 root root  157063 Aug 16  2014 COCO_train2014_000000581223.jpg
# -rw-rw-r-- 1 root root   48234 Aug 16  2014 COCO_train2014_000000581227.jpg
# -rw-rw-r-- 1 root root  307331 Aug 16  2014 COCO_train2014_000000581233.jpg
# -rw-rw-r-- 1 root root  143925 Aug 16  2014 COCO_train2014_000000581249.jpg
# -rw-rw-r-- 1 root root  146471 Aug 16  2014 COCO_train2014_000000581256.jpg
# -rw-rw-r-- 1 root root  136587 Aug 16  2014 COCO_train2014_000000581258.jpg
# -rw-rw-r-- 1 root root  150446 Aug 16  2014 COCO_train2014_000000581277.jpg
# -rw-rw-r-- 1 root root  128216 Aug 16  2014 COCO_train2014_000000581278.jpg
# -rw-rw-r-- 1 root root  225386 Aug 16  2014 COCO_train2014_000000581282.jpg
# -rw-rw-r-- 1 root root  171057 Aug 16  2014 COCO_train2014_000000581283.jpg
# -rw-rw-r-- 1 root root   83534 Aug 16  2014 COCO_train2014_000000581285.jpg
# -rw-rw-r-- 1 root root  227437 Aug 16  2014 COCO_train2014_000000581293.jpg
# -rw-rw-r-- 1 root root  207846 Aug 16  2014 COCO_train2014_000000581297.jpg
# -rw-rw-r-- 1 root root   58235 Aug 16  2014 COCO_train2014_000000581302.jpg
# -rw-rw-r-- 1 root root   78619 Aug 16  2014 COCO_train2014_000000581309.jpg
# -rw-rw-r-- 1 root root  225857 Aug 16  2014 COCO_train2014_000000581310.jpg
# -rw-rw-r-- 1 root root  184559 Aug 16  2014 COCO_train2014_000000581326.jpg
# -rw-rw-r-- 1 root root   58258 Aug 16  2014 COCO_train2014_000000581346.jpg
# -rw-rw-r-- 1 root root  170706 Aug 16  2014 COCO_train2014_000000581348.jpg
# -rw-rw-r-- 1 root root  131611 Aug 16  2014 COCO_train2014_000000581351.jpg
# -rw-rw-r-- 1 root root  166933 Aug 16  2014 COCO_train2014_000000581354.jpg
# -rw-rw-r-- 1 root root  158171 Aug 16  2014 COCO_train2014_000000581362.jpg
# -rw-rw-r-- 1 root root  241087 Aug 16  2014 COCO_train2014_000000581391.jpg
# -rw-rw-r-- 1 root root  129756 Aug 16  2014 COCO_train2014_000000581392.jpg
# -rw-rw-r-- 1 root root  111288 Aug 16  2014 COCO_train2014_000000581393.jpg
# -rw-rw-r-- 1 root root  181659 Aug 16  2014 COCO_train2014_000000581396.jpg
# -rw-rw-r-- 1 root root   64188 Aug 16  2014 COCO_train2014_000000581409.jpg
# -rw-rw-r-- 1 root root  217481 Aug 16  2014 COCO_train2014_000000581419.jpg
# -rw-rw-r-- 1 root root  227120 Aug 16  2014 COCO_train2014_000000581423.jpg
# -rw-rw-r-- 1 root root  161719 Aug 16  2014 COCO_train2014_000000581425.jpg
# -rw-rw-r-- 1 root root  224416 Aug 16  2014 COCO_train2014_000000581446.jpg
# -rw-rw-r-- 1 root root  208348 Aug 16  2014 COCO_train2014_000000581466.jpg
# -rw-rw-r-- 1 root root  233083 Aug 16  2014 COCO_train2014_000000581481.jpg
# -rw-rw-r-- 1 root root  233465 Aug 16  2014 COCO_train2014_000000581486.jpg
# -rw-rw-r-- 1 root root   77728 Aug 16  2014 COCO_train2014_000000581495.jpg
# -rw-rw-r-- 1 root root  109826 Aug 16  2014 COCO_train2014_000000581499.jpg
# -rw-rw-r-- 1 root root  241025 Aug 16  2014 COCO_train2014_000000581507.jpg
# -rw-rw-r-- 1 root root  150887 Aug 16  2014 COCO_train2014_000000581513.jpg
# -rw-rw-r-- 1 root root  147374 Aug 16  2014 COCO_train2014_000000581518.jpg
# -rw-rw-r-- 1 root root  184769 Aug 16  2014 COCO_train2014_000000581539.jpg
# -rw-rw-r-- 1 root root  165158 Aug 16  2014 COCO_train2014_000000581553.jpg
# -rw-rw-r-- 1 root root   79136 Aug 16  2014 COCO_train2014_000000581563.jpg
# -rw-rw-r-- 1 root root  190218 Aug 16  2014 COCO_train2014_000000581566.jpg
# -rw-rw-r-- 1 root root  110908 Aug 16  2014 COCO_train2014_000000581571.jpg
# -rw-rw-r-- 1 root root  207734 Aug 16  2014 COCO_train2014_000000581572.jpg
# -rw-rw-r-- 1 root root  183030 Aug 16  2014 COCO_train2014_000000581582.jpg
# -rw-rw-r-- 1 root root  239482 Aug 16  2014 COCO_train2014_000000581594.jpg
# -rw-rw-r-- 1 root root   75987 Aug 16  2014 COCO_train2014_000000581601.jpg
# -rw-rw-r-- 1 root root  198271 Aug 16  2014 COCO_train2014_000000581605.jpg
# -rw-rw-r-- 1 root root   83991 Aug 16  2014 COCO_train2014_000000581629.jpg
# -rw-rw-r-- 1 root root  149683 Aug 16  2014 COCO_train2014_000000581637.jpg
# -rw-rw-r-- 1 root root   93701 Aug 16  2014 COCO_train2014_000000581657.jpg
# -rw-rw-r-- 1 root root  167910 Aug 16  2014 COCO_train2014_000000581662.jpg
# -rw-rw-r-- 1 root root  118593 Aug 16  2014 COCO_train2014_000000581667.jpg
# -rw-rw-r-- 1 root root  204978 Aug 16  2014 COCO_train2014_000000581668.jpg
# -rw-rw-r-- 1 root root  111685 Aug 16  2014 COCO_train2014_000000581670.jpg
# -rw-rw-r-- 1 root root  126742 Aug 16  2014 COCO_train2014_000000581674.jpg
# -rw-rw-r-- 1 root root   61019 Aug 16  2014 COCO_train2014_000000581686.jpg
# -rw-rw-r-- 1 root root  175403 Aug 16  2014 COCO_train2014_000000581697.jpg
# -rw-rw-r-- 1 root root  132000 Aug 16  2014 COCO_train2014_000000581704.jpg
# -rw-rw-r-- 1 root root  141210 Aug 16  2014 COCO_train2014_000000581708.jpg
# -rw-rw-r-- 1 root root  123487 Aug 16  2014 COCO_train2014_000000581709.jpg
# -rw-rw-r-- 1 root root  141185 Aug 16  2014 COCO_train2014_000000581711.jpg
# -rw-rw-r-- 1 root root  197109 Aug 16  2014 COCO_train2014_000000581712.jpg
# -rw-rw-r-- 1 root root  159838 Aug 16  2014 COCO_train2014_000000581715.jpg
# -rw-rw-r-- 1 root root  134359 Aug 16  2014 COCO_train2014_000000581719.jpg
# -rw-rw-r-- 1 root root   21932 Aug 16  2014 COCO_train2014_000000581732.jpg
# -rw-rw-r-- 1 root root  215850 Aug 16  2014 COCO_train2014_000000581738.jpg
# -rw-rw-r-- 1 root root  143059 Aug 16  2014 COCO_train2014_000000581739.jpg
# -rw-rw-r-- 1 root root  185160 Aug 16  2014 COCO_train2014_000000581744.jpg
# -rw-rw-r-- 1 root root   74459 Aug 16  2014 COCO_train2014_000000581766.jpg
# -rw-rw-r-- 1 root root  170040 Aug 16  2014 COCO_train2014_000000581770.jpg
# -rw-rw-r-- 1 root root  147382 Aug 16  2014 COCO_train2014_000000581789.jpg
# -rw-rw-r-- 1 root root  278894 Aug 16  2014 COCO_train2014_000000581795.jpg
# -rw-rw-r-- 1 root root  203116 Aug 16  2014 COCO_train2014_000000581797.jpg
# -rw-rw-r-- 1 root root  338163 Aug 16  2014 COCO_train2014_000000581813.jpg
# -rw-rw-r-- 1 root root  191392 Aug 16  2014 COCO_train2014_000000581815.jpg
# -rw-rw-r-- 1 root root  111137 Aug 16  2014 COCO_train2014_000000581821.jpg
# -rw-rw-r-- 1 root root  173685 Aug 16  2014 COCO_train2014_000000581835.jpg
# -rw-rw-r-- 1 root root  190439 Aug 16  2014 COCO_train2014_000000581839.jpg
# -rw-rw-r-- 1 root root  245635 Aug 16  2014 COCO_train2014_000000581857.jpg
# -rw-rw-r-- 1 root root  140823 Aug 16  2014 COCO_train2014_000000581860.jpg
# -rw-rw-r-- 1 root root  234610 Aug 16  2014 COCO_train2014_000000581873.jpg
# -rw-rw-r-- 1 root root   67788 Aug 16  2014 COCO_train2014_000000581880.jpg
# -rw-rw-r-- 1 root root  332403 Aug 16  2014 COCO_train2014_000000581881.jpg
# -rw-rw-r-- 1 root root   96290 Aug 16  2014 COCO_train2014_000000581882.jpg
# -rw-rw-r-- 1 root root  136539 Aug 16  2014 COCO_train2014_000000581884.jpg
# -rw-rw-r-- 1 root root   74143 Aug 16  2014 COCO_train2014_000000581900.jpg
# -rw-rw-r-- 1 root root  249377 Aug 16  2014 COCO_train2014_000000581903.jpg
# -rw-rw-r-- 1 root root  238470 Aug 16  2014 COCO_train2014_000000581904.jpg
# -rw-rw-r-- 1 root root  267165 Aug 16  2014 COCO_train2014_000000581906.jpg
# -rw-rw-r-- 1 root root  144814 Aug 16  2014 COCO_train2014_000000581909.jpg
# -rw-rw-r-- 1 root root   70995 Aug 16  2014 COCO_train2014_000000581921.jpg
# images.shape: torch.Size([10, 3, 224, 224])
# captions.shape: torch.Size([10, 14])

# %% [markdown]
# Each time you run the code cell above, a different caption length is sampled, and a different batch of training data is returned.  Run the code cell multiple times to check this out!
#
# You will train your model in the next notebook in this sequence (**2_Training.ipynb**). This code for generating training batches will be provided to you.
#
# > Before moving to the next notebook in the sequence (**2_Training.ipynb**), you are strongly encouraged to take the time to become very familiar with the code in  **data_loader.py** and **vocabulary.py**.  **Step 1** and **Step 2** of this notebook are designed to help facilitate a basic introduction and guide your understanding.  However, our description is not exhaustive, and it is up to you (as part of the project) to learn how to best utilize these files to complete the project.  __You should NOT amend any of the code in either *data_loader.py* or *vocabulary.py*.__
#
# In the next steps, we focus on learning how to specify a CNN-RNN architecture in PyTorch, towards the goal of image captioning.

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: Experiment with the CNN Encoder
#
# Run the code cell below to import `EncoderCNN` and `DecoderRNN` from **model.py**.

# %%
# Watch for any changes in model.py, and re-load it automatically.
# %load_ext autoreload
# %autoreload 2
# !wget https://raw.githubusercontent.com/hhosseinian/ImageCaptioning/main/model.py #Uncomment if you run on google colab
# Import EncoderCNN and DecoderRNN.
from model import EncoderCNN, DecoderRNN
# Out:
# --2024-07-28 08:15:15--  https://raw.githubusercontent.com/hhosseinian/ImageCaptioning/main/model.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3413 (3.3K) [text/plain]
# Saving to: ‘model.py’
#
# model.py            100%[===================>]   3.33K  --.-KB/s    in 0s
#
# 2024-07-28 08:15:15 (41.6 MB/s) - ‘model.py’ saved [3413/3413]

# %% [markdown]
# In the next code cell we define a `device` that you will use move PyTorch tensors to GPU (if CUDA is available).  Run this code cell before continuing.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Run the code cell below to instantiate the CNN encoder in `encoder`.
#
# The pre-processed images from the batch in **Step 2** of this notebook are then passed through the encoder, and the output is stored in `features`.

# %%
# Specify the dimensionality of the image embedding.
embed_size = 256

#-#-#-# Do NOT modify the code below this line. #-#-#-#

# Initialize the encoder. (Optional: Add additional arguments if necessary.)
encoder = EncoderCNN(embed_size)

# Move the encoder to GPU if CUDA is available.
encoder.to(device)

# Move last batch of images (from Step 2) to GPU if CUDA is available.
images = images.to(device)

# Pass the images through the encoder.
features = encoder(images)

print('type(features):', type(features))
print('features.shape:', features.shape)

# Check that your encoder satisfies some requirements of the project! :D
assert type(features)==torch.Tensor, "Encoder output needs to be a PyTorch Tensor."
assert (features.shape[0]==batch_size) & (features.shape[1]==embed_size), "The shape of the encoder output is incorrect."
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 77.3MB/s]
# type(features): <class 'torch.Tensor'>
# features.shape: torch.Size([10, 256])

# %% [markdown]
# The encoder that we provide to you uses the pre-trained ResNet-50 architecture (with the final fully-connected layer removed) to extract features from a batch of pre-processed images.  The output is then flattened to a vector, before being passed through a `Linear` layer to transform the feature vector to have the same size as the word embedding.
#
# ![Encoder](https://github.com/hhosseinian/ImageCaptioning/blob/main/.ipynb_checkpoints/images/encoder.png?raw=1)
#
# You are welcome (and encouraged) to amend the encoder in **model.py**, to experiment with other architectures.  In particular, consider using a [different pre-trained model architecture](http://pytorch.org/docs/master/torchvision/models.html).  You may also like to [add batch normalization](http://pytorch.org/docs/master/nn.html#normalization-layers).
#
# > You are **not** required to change anything about the encoder.
#
# For this project, you **must** incorporate a pre-trained CNN into your encoder.  Your `EncoderCNN` class must take `embed_size` as an input argument, which will also correspond to the dimensionality of the input to the RNN decoder that you will implement in Step 4.  When you train your model in the next notebook in this sequence (**2_Training.ipynb**), you are welcome to tweak the value of `embed_size`.
#
# If you decide to modify the `EncoderCNN` class, save **model.py** and re-execute the code cell above.  If the code cell returns an assertion error, then please follow the instructions to modify your code before proceeding.  The assert statements ensure that `features` is a PyTorch tensor with shape `[batch_size, embed_size]`.

# %% [markdown]
# <a id='step4'></a>
# ## Step 4: Implement the RNN Decoder
#
# Before executing the next code cell, you must write `__init__` and `forward` methods in the `DecoderRNN` class in **model.py**.  (Do **not** write the `sample` method yet - you will work with this method when you reach **3_Inference.ipynb**.)
#
# > The `__init__` and `forward` methods in the `DecoderRNN` class are the only things that you **need** to modify as part of this notebook.  You will write more implementations in the notebooks that appear later in the sequence.
#
# Your decoder will be an instance of the `DecoderRNN` class and must accept as input:
# - the PyTorch tensor `features` containing the embedded image features (outputted in Step 3, when the last batch of images from Step 2 was passed through `encoder`), along with
# - a PyTorch tensor corresponding to the last batch of captions (`captions`) from Step 2.
#
# Note that the way we have written the data loader should simplify your code a bit.  In particular, every training batch will contain pre-processed captions where all have the same length (`captions.shape[1]`), so **you do not need to worry about padding**.
# > While you are encouraged to implement the decoder described in [this paper](https://arxiv.org/pdf/1411.4555.pdf), you are welcome to implement any architecture of your choosing, as long as it uses at least one RNN layer, with hidden dimension `hidden_size`.
#
# Although you will test the decoder using the last batch that is currently stored in the notebook, your decoder should be written to accept an arbitrary batch (of embedded image features and pre-processed captions [where all captions have the same length]) as input.
#
# ![Decoder](https://github.com/hhosseinian/ImageCaptioning/blob/main/.ipynb_checkpoints/images/decoder.png?raw=1)
#
# In the code cell below, `outputs` should be a PyTorch tensor with size `[batch_size, captions.shape[1], vocab_size]`.  Your output should be designed such that `outputs[i,j,k]` contains the model's predicted score, indicating how likely the `j`-th token in the `i`-th caption in the batch is the `k`-th token in the vocabulary.  In the next notebook of the sequence (**2_Training.ipynb**), we provide code to supply these scores to the [`torch.nn.CrossEntropyLoss`](http://pytorch.org/docs/master/nn.html#torch.nn.CrossEntropyLoss) optimizer in PyTorch.

# %%
# Specify the number of features in the hidden state of the RNN decoder.
hidden_size = 512

#-#-#-# Do NOT modify the code below this line. #-#-#-#

# Store the size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the decoder.
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move the decoder to GPU if CUDA is available.
decoder.to(device)

# Move last batch of captions (from Step 1) to GPU if CUDA is available
captions = captions.to(device)

# Pass the encoder output and captions through the decoder.
outputs = decoder(features, captions)

print('type(outputs):', type(outputs))
print('outputs.shape:', outputs.shape)

# Check that your decoder satisfies some requirements of the project! :D
assert type(outputs)==torch.Tensor, "Decoder output needs to be a PyTorch Tensor."
assert (outputs.shape[0]==batch_size) & (outputs.shape[1]==captions.shape[1]) & (outputs.shape[2]==vocab_size), "The shape of the decoder output is incorrect."
# Out:
# type(outputs): <class 'torch.Tensor'>
# outputs.shape: torch.Size([10, 14, 3185])

# %% [markdown]
# When you train your model in the next notebook in this sequence (**2_Training.ipynb**), you are welcome to tweak the value of `hidden_size`.
